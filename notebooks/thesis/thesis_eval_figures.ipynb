# %%
# %pylab inline

import seaborn as sns

from sigvisa.plotting.event_heatmap import EventHeatmap
from sigvisa.source.event import get_event
from sigvisa import Sigvisa
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Chapter 8 (Evaluation)

# %% [markdown]
# ## Event locations

# %%
train_evids = np.loadtxt("train_evids.txt")
train_evs = [get_event(evid=int(evid)) for evid in train_evids]
train_locs = [(ev.lon, ev.lat) for ev in train_evs]
s = Sigvisa()

stas = "ANMO,ELK,ILAR,KDAK,NEW,NVAR,PDAR,PFO,TXAR,ULM,YBH,YKA".split(",")
sta_locs = np.asarray([s.earthmodel.site_info(sta, 0)[:2] for sta in stas])

stas1 = "ANMO,ELK,NEW,NVAR,PDAR,PFO,TXAR,ULM,YBH,YKA".split(",")
sta1_locs = np.asarray([s.earthmodel.site_info(sta, 0)[:2] for sta in stas1])

stas2 = ["KDAK","ILAR"]
sta2_locs = np.asarray([s.earthmodel.site_info(sta, 0)[:2] for sta in stas2])

# %%
hm = EventHeatmap(f=None, calc=False, left_lon=-130, right_lon=-90, bottom_lat=27, top_lat=51)

f = plt.figure(figsize=(15, 15))
ax = gca()
hm.init_bmap(axes=ax, nofillcontinents=True, projection="aea", lon_0 = -111, lat_0=40)
hm.plot_earth(y_fontsize=14, x_fontsize=14)

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in train_locs ])
#scplot = hm.bmap.scatter(normed_locations[:, 0], normed_locations[:, 1], 
#                         alpha=0.3, s=6, marker=".", color="red")

hm.plot_locations(normed_locations, marker=".", ms=6, mec="none", mew=0,
                    alpha=0.3, color="red")


hm.plot_locations(sta1_locs, labels=stas1, marker="^", ms=10, mfc="none", mec="blue", mew=3, alpha=1,
                    offmap_arrows=True, arrow_color="blue", 
                  label_x_off=12, label_y_off=0, label_pts=14,
                 edge_x_off=-60, edge_y_off=-20)

hm.plot_locations(sta2_locs, labels=stas2, marker="^", ms=10, mfc="none", mec="blue", mew=3, alpha=1,
                    offmap_arrows=True, arrow_color="blue", 
                  label_x_off=-45, label_y_off=0, label_pts=14,
                 edge_x_off=-45, edge_y_off=-20)

hm.drawline((-126, 33), (-100, 33), color='black', lw=6, curve_map=True)
hm.drawline((-126, 33), (-126, 49), color='black', lw=6, curve_map=True)
hm.drawline((-126, 49), (-100, 49), color='black', lw=6, curve_map=True)
hm.drawline((-100, 33), (-100, 49), color='black', lw=6, curve_map=True)
# Out:
# ANMO 12 0 2325115.54747 679657.702405
# ELK 12 0 1552699.28208 1321639.40904
# NEW 12 0 1451591.06202 2161396.78225
# NVAR 12 0 1273976.30181 1081794.81776
# PDAR 12 0 2027546.39604 1538807.01316
# PFO 12 0 1401914.81214 536631.221869
# TXAR 12 0 2630497.24685 80136.6851269
# ULM 12 0 3000554.11093 2456014.17072
# YBH 12 0 940286.576572 1486655.69954
# YKA 12 -20 1839150.24706 2589252.0033
# KDAK -45 -20 637172.881487 2589252.0033
# ILAR -45 -20 1182975.46702 2589252.0033
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Event clusters

# %%
from sigvisa.utils.geog import dist_km
import scipy.spatial


centers = np.loadtxt("/home/dmoore/python/sigvisa/isc_clusters")[:, :2]
vor = scipy.spatial.Voronoi(centers)


def cluster_idx(lon, lat):
    dists = [dist_km((lon, lat), (clon, clat)) for (clon, clat, _) in centers]
    return np.argmin(dists)

s = Sigvisa()
hm = EventHeatmap(f=None, left_lon=-126, right_lon=-100, top_lat=49, bottom_lat=33, calc=True, n=0)

sns.set_style("white")

f = plt.figure(figsize=(15, 15))

ax = plt.gca()

v = scipy.spatial.voronoi_plot_2d(vor, ax=ax, show_vertices=False)
hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in train_locs ])
hm.plot_locations(normed_locations, marker=".", ms=6, mec="none", mew=0,
                    alpha=0.3, color="red")

# %% [markdown]
# ## Event prior

# %%
def prior_lp(lon, lat):
    lp = s.sigmodel.event_location_prior_logprob(lon, lat, -1)
    #if lp < -20:
    #    lp = s.sigmodel.event_location_prior_logprob(-101, 48, -1)
    return lp

def prior_prob(lon, lat):
    return np.exp(prior_lp(lon, lat))

s = Sigvisa()
hm = EventHeatmap(f=prior_lp, left_lon=-126, right_lon=-100, top_lat=49, bottom_lat=33, calc=True, n=500)

f = plt.figure(figsize=(15, 15))
ax = plt.gca()
hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")
hm.plot_earth(y_fontsize=20, x_fontsize=20)

cm = matplotlib.cm.get_cmap('Reds')
hm.plot_density(smooth=True, cm=cm, colorbar=False, vmin=-1.0, zorder=-5)

# %%
# compute dynamic range
minlp = np.min(hm.fvals[hm.fvals > -40])
maxlp = np.max(hm.fvals)
print minlp, maxlp
print "dynamic range", maxlp - minlp
# Out:
# -6.37067948378 5.02126728263
# dynamic range 11.3919467664

# %% [markdown]
# ## Event score distribution

# %%
from sigvisa.graph.serialization import load_serialized_from_file

evdicts, uadicts_by_sta = load_serialized_from_file("/home/dmoore/python/sigvisa/cloud/remote_jobs/test_omg_seed2/merged.tgz")
scores = [evd["score"] for evd in evdicts]

sns.set_context("talk", font_scale=1.5)
sns.set_style("whitegrid")
f = plt.figure()
ax = gca()
sns.distplot(scores, kde=False, norm_hist=True)
ax.set_xlabel("event score")
#ax.set_ylim([0, 170])

# %% [markdown]
# ## De novo events

# %%
denovo_evids = np.loadtxt("/home/dmoore/python/sigvisa/notebooks/thesis/denovo_evids.txt")
denovo_evs = [get_event(evid=evid) for evid in denovo_evids]
denovo_locs = [(ev.lon, ev.lat) for ev in denovo_evs]

s = Sigvisa()
hm = EventHeatmap(f=None, left_lon=-126, right_lon=-100, top_lat=49, bottom_lat=33, calc=True, n=0)

sns.set_style("white")

f = plt.figure(figsize=(15, 15))
ax = plt.gca()
hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")
hm.plot_earth(y_fontsize=14, x_fontsize=14)

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in train_locs ])
hm.plot_locations(normed_locations, marker=".", ms=6, mec="none", mew=0,
                    alpha=0.3, color="red")

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in denovo_locs ])
hm.plot_locations(normed_locations, marker="*", ms=12, mec="blue", mew=0,
                    alpha=0.65, color="blue")

# %% [markdown]
# # Test bulletin

# %%
import os
import numpy as np

basedir = "/home/dmoore/python/sigvisa/notebooks/thesis/results/"

isc_bulletin = np.loadtxt(os.path.join(basedir, "isc_bulletin_visa.txt"))
isc_wells_bulletin = np.loadtxt(os.path.join(basedir, "merged_origins.txt"))
isc_wells_mb_bulletin = np.loadtxt(os.path.join(basedir, "merged_origins_mbcorrected.txt"))

isc_wells_analyst_bulletin = np.loadtxt(os.path.join(basedir, "merged_analyst.txt"))

def present(bulletin, ev):
    for ev2 in bulletin:
        if np.max(np.abs(ev2[:5] - ev[:5])) < 0.1:
            return True
    return False

isc_wells_new = np.array([ev for ev in isc_wells_bulletin if not present(isc_bulletin, ev)])

# %%
s = Sigvisa()
hm = EventHeatmap(f=None, left_lon=-126, right_lon=-100, top_lat=49, bottom_lat=33, calc=True, n=0)

sns.set_style("white")

f = plt.figure(figsize=(15, 15))
ax = plt.gca()
hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")
hm.plot_earth(y_fontsize=14, x_fontsize=14)


normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in isc_bulletin ])
hm.plot_locations(normed_locations, marker="+", ms=10, mec="red", mew=1,
                    alpha=0.5, color="red")

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in isc_wells_new ])
hm.plot_locations(normed_locations, marker=".", ms=10, mec="none", mew=0,
                    alpha=0.1, color="purple")



stas = "ANMO,ELK,ILAR,KDAK,NEW,NVAR,PDAR,PFO,TXAR,ULM,YBH,YKA".split(",")
sta_locations = [s.earthmodel.site_info(n, 0)[0:2] for n in stas]
hm.plot_locations(sta_locations, labels=stas, offmap_arrows=True,
                  marker="^", ms=10, mec="blue", mew=3,
                  alpha=1.0, mfc="none", arrow_color="blue", 
                  label_x_off=-10, label_y_off=-18, label_pts=10,)
    


#normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in denovo_locs ])
#hm.plot_locations(normed_locations, marker="*", ms=12, mec="blue", mew=0,
#                    alpha=0.65, color="blue")
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
s = Sigvisa()
hm = EventHeatmap(f=None, left_lon=-115.1, right_lon=-114.5, top_lat=41.4, bottom_lat=40.8, calc=True, n=0)

sns.set_style("white")

f = plt.figure(figsize=(8, 8))
ax = plt.gca()
hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")
hm.plot_earth(y_fontsize=14, x_fontsize=14, interval=0.3)

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in isc_bulletin ])
hm.plot_locations(normed_locations, marker="+", ms=10, mec="red", mew=1,
                    alpha=0.5, color="red")

normed_locations = np.array([hm.normalize_lonlat(*location[:2]) for location in isc_wells_new ])
hm.plot_locations(normed_locations, marker=".", ms=10, mec="none", mew=0,
                    alpha=0.1, color="purple")

# %% [markdown]
# # Evaluation curves and plots

# %%
import os
import numpy as np

basedir = "/home/dmoore/python/sigvisa/notebooks/thesis/results/"

netvisa_bulletin = np.loadtxt(os.path.join(basedir, "visa_bulletin_visa.txt"))
sel3_bulletin = np.loadtxt(os.path.join(basedir, "sel3_bulletin_sel3.txt"))
leb_bulletin = np.loadtxt(os.path.join(basedir, "leb_bulletin_leb.txt"))

sigvisa_bulletin_merged_123 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_seed123_sum.txt"))
sigvisa_bulletin_merged_123hf = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test123_12.txt"))
sigvisa_bulletin_seed1 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test_omg_seed1.txt"))
sigvisa_bulletin_seed2 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test_omg_seed2.txt"))
sigvisa_bulletin_seed3 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test_omg_seed3.txt"))

sigvisa_bulletin_hf11 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test_highfreq_seed11.txt"))
sigvisa_bulletin_hf12 = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_test_highfreq_seed12.txt"))


isc_bulletin = np.loadtxt(os.path.join(basedir, "isc_bulletin_visa.txt"))
isc_wells_mb_bulletin = np.loadtxt(os.path.join(basedir, "merged_origins_mbcorrected.txt"))
isc_wellslarge_bulletin = np.loadtxt(os.path.join(basedir, "merged_origins_large.txt"))

isc_wells_analyst_bulletin = np.loadtxt(os.path.join(basedir, "merged_analyst.txt"))


truth = isc_wells_bulletin

# %%
from sigvisa.results.compare import f1_and_error

kwargs = {
    'max_delta_deg': 2.0,
    'max_delta_time': 50.0
}

# threshold to match precision of SEL3
sigvisa_thresholded = np.asarray([ev for ev in sigvisa_bulletin_merged_123hf if ev[5] > 160])
print len(sigvisa_thresholded)
_, thresholded_precision, thresholded_recall, _, _ = f1_and_error(truth, sigvisa_thresholded, **kwargs)
print "precision", thresholded_precision, "recall", thresholded_recall
# Out:
# 393
# precision 51.3994910941 recall 19.3116634799

# %%
_, netvisa_prec, netvisa_recall, netvisa_meanerr, netvisa_errors = f1_and_error(truth, netvisa_bulletin, **kwargs)

print netvisa_prec, netvisa_recall
print leb_precision, leb_recall
# Out:
# 54.6762589928 7.26577437859
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-84667987bfc1> in <module>()
#       2
#       3 print netvisa_prec, netvisa_recall
# ----> 4 print leb_precision, leb_recall
#
# NameError: name 'leb_precision' is not defined

# %% [markdown]
# # LEB events not in ISC

# %%
from sigvisa.results.compare import find_matching

indices = find_matching(isc_bulletin, leb_bulletin, **kwargs)
unmatched_events = set(np.arange(len(leb_bulletin))) - set([j for (i,j) in  indices])
print unmatched_events
# Out:
# set([1, 4, 10, 12, 13, 14, 15, 19, 27, 28, 30, 31, 38, 39, 45, 46, 49, 51, 52, 54, 55, 56, 57, 58, 62, 63, 66, 69, 72, 77, 83, 84, 85, 86, 87, 92, 93])

# %%
print indices
print isc_bulletin[3,:]
print leb_bulletin[3,:]
# Out:
# [(0, 0), (1, 2), (3, 3), (4, 5), (5, 6), (6, 7), (7, 8), (8, 9), (10, 11), (11, 16), (12, 17), (14, 18), (15, 20), (16, 21), (17, 22), (19, 23), (21, 24), (23, 25), (24, 26), (25, 29), (26, 32), (27, 33), (28, 34), (30, 35), (31, 36), (32, 37), (35, 40), (37, 41), (38, 42), (39, 43), (40, 44), (41, 47), (42, 48), (43, 50), (44, 53), (53, 59), (55, 60), (56, 61), (63, 64), (64, 65), (67, 67), (68, 68), (70, 70), (71, 71), (73, 73), (75, 74), (76, 75), (77, 76), (78, 78), (79, 79), (80, 80), (82, 81), (85, 82), (88, 88), (89, 89), (90, 90), (96, 91), (100, 94), (101, 95)]
# [ -1.14900300e+02   4.11590000e+01   1.00000000e+01   1.20365684e+09
#    3.20000000e+00   0.00000000e+00   3.37534700e+06]
# [ -1.14921590e+02   4.11992080e+01   0.00000000e+00   1.20365684e+09
#    3.18826590e+00   0.00000000e+00   4.61653900e+06]

# %%
print "unmatched leb events:"
print leb_bulletin[19,:]
print leb_bulletin[83,:]
# Out:
# unmatched leb events
# [ -1.14883450e+02   4.11050590e+01   0.00000000e+00   1.20367808e+09
#   -9.99000000e+02   0.00000000e+00   4.61942700e+06]
# [ -1.14924310e+02   4.12255310e+01   0.00000000e+00   1.20438034e+09
#   -9.99000000e+02   0.00000000e+00   4.62866400e+06]

# %% [markdown]
# # Merged ISC/Wells prec/recall

# %%
from sigvisa.results.evaluate_serialized import precision_recall_curve
from sigvisa.results.compare import f1_and_error

kwargs = {
    'max_delta_deg': 2.0,
    'max_delta_time': 50.0
}
freq=15

netvisa_precs, netvisa_recalls = precision_recall_curve(netvisa_bulletin, truth, 
                                                        freq=freq, cheap=True, **kwargs)
_, _, _, netvisa_meanerr, netvisa_errors = f1_and_error(truth, netvisa_bulletin, **kwargs)


sigvisa_precs, sigvisa_recalls = precision_recall_curve(sigvisa_bulletin_merged_123, truth, 
                                                        freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_meanerr, sigvisa_errors = f1_and_error(truth, sigvisa_bulletin_merged_123, **kwargs)

sigvisa_withhf_precs, sigvisa_withhf_recalls = precision_recall_curve(sigvisa_bulletin_merged_123hf, truth, 
                                                                      freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_withhf_meanerr, sigvisa_withhf_errors = f1_and_error(truth, sigvisa_bulletin_merged_123hf, **kwargs)

sigvisa_seed1_precs, sigvisa_seed1_recalls = precision_recall_curve(sigvisa_bulletin_seed1, truth, 
                                                                    freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_seed1_meanerr, sigvisa_seed1_errors = f1_and_error(truth, sigvisa_bulletin_seed1, **kwargs)

sigvisa_seed2_precs, sigvisa_seed2_recalls = precision_recall_curve(sigvisa_bulletin_seed2, truth, 
                                                                    freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_seed2_meanerr, sigvisa_seed2_errors = f1_and_error(truth, sigvisa_bulletin_seed1, **kwargs)

sigvisa_seed3_precs, sigvisa_seed3_recalls = precision_recall_curve(sigvisa_bulletin_seed3, truth,
                                                                    freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_seed3_meanerr, sigvisa_seed3_errors = f1_and_error(truth, sigvisa_bulletin_seed1, **kwargs)


sigvisa_hf11_precs, sigvisa_hf11_recalls = precision_recall_curve(sigvisa_bulletin_hf11, truth,
                                                                    freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_hf11_meanerr, sigvisa_hf11_errors = f1_and_error(truth, sigvisa_bulletin_hf11, **kwargs)

sigvisa_hf12_precs, sigvisa_hf12_recalls = precision_recall_curve(sigvisa_bulletin_hf12, truth,
                                                                    freq=freq, cheap=True, **kwargs)
_, _, _, sigvisa_hf12_meanerr, sigvisa_hf12_errors = f1_and_error(truth, sigvisa_bulletin_hf12, **kwargs)

_, leb_precision, leb_recall, leb_meanerr, leb_errors = f1_and_error(truth, leb_bulletin, **kwargs)
_, sel3_precision, sel3_recall, sel3_meanerr, sel3_errors = f1_and_error(truth, sel3_bulletin, **kwargs)
# Out:
# 0 events threshold 176.7 precision 100.0 recall 0.1
# 15 events threshold 41.0 precision 87.5 recall 1.3
# 30 events threshold 33.1 precision 83.9 recall 2.5
# 45 events threshold 25.6 precision 73.9 recall 3.3
# 60 events threshold 20.8 precision 73.8 recall 4.3
# 75 events threshold 17.4 precision 73.7 recall 5.4
# 90 events threshold 13.6 precision 72.5 recall 6.3
# 105 events threshold 10.2 precision 66.0 recall 6.7
# 120 events threshold 6.9 precision 61.2 recall 7.1
# 135 events threshold 3.6 precision 55.1 recall 7.2
# 0 events threshold 2253.6 precision 100.0 recall 0.1
# 15 events threshold 1058.3 precision 100.0 recall 1.5
# 30 events threshold 841.8 precision 93.5 recall 2.8
# 45 events threshold 629.5 precision 82.6 recall 3.6
# 60 events threshold 545.0 precision 83.6 recall 4.9
# 75 events threshold 479.1 precision 85.5 recall 6.2
# 90 events threshold 444.3 precision 85.7 recall 7.5
# 105 events threshold 395.4 precision 82.1 recall 8.3
# 120 events threshold 364.7 precision 79.3 recall 9.2
# 135 events threshold 344.7 precision 78.7 recall 10.2
# 150 events threshold 319.3 precision 74.8 recall 10.8
# 165 events threshold 288.0 precision 72.9 recall 11.6
# 180 events threshold 269.8 precision 70.7 recall 12.2
# 195 events threshold 259.0 precision 68.9 recall 12.9
# 210 events threshold 243.4 precision 66.4 recall 13.4
# 225 events threshold 226.1 precision 65.5 recall 14.1
# 240 events threshold 214.8 precision 64.3 recall 14.8
# 255 events threshold 203.9 precision 63.3 recall 15.5
# 270 events threshold 196.3 precision 60.9 recall 15.8
# 285 events threshold 187.1 precision 58.0 recall 15.9
# 300 events threshold 176.6 precision 56.5 recall 16.3
# 315 events threshold 172.7 precision 54.4 recall 16.4
# 330 events threshold 165.8 precision 53.2 recall 16.8
# 345 events threshold 161.3 precision 52.3 recall 17.3
# 360 events threshold 155.1 precision 50.7 recall 17.5
# 375 events threshold 150.1 precision 48.9 recall 17.6
# 390 events threshold 147.0 precision 47.6 recall 17.8
# 405 events threshold 141.5 precision 45.8 recall 17.8
# 420 events threshold 138.7 precision 44.9 recall 18.1
# 435 events threshold 133.7 precision 44.0 recall 18.4
# 450 events threshold 131.1 precision 43.5 recall 18.7
# 465 events threshold 128.7 precision 42.9 recall 19.1
# 480 events threshold 125.2 precision 42.4 recall 19.5
# 495 events threshold 122.6 precision 41.7 recall 19.8
# 510 events threshold 119.6 precision 41.1 recall 20.1
# 525 events threshold 117.4 precision 40.3 recall 20.3
# 540 events threshold 115.4 precision 39.7 recall 20.6
# 555 events threshold 112.5 precision 39.0 recall 20.7
# 570 events threshold 110.1 precision 38.2 recall 20.8
# 585 events threshold 108.1 precision 37.4 recall 20.9
# 600 events threshold 106.2 precision 36.4 recall 20.9
# 615 events threshold 104.8 precision 36.2 recall 21.3
# 630 events threshold 102.6 precision 35.5 recall 21.4
# 645 events threshold 101.0 precision 34.8 recall 21.5
# 660 events threshold 99.5 precision 34.3 recall 21.7
# 675 events threshold 98.0 precision 34.0 recall 22.0
# 690 events threshold 96.9 precision 33.3 recall 22.0
# 705 events threshold 95.5 precision 32.7 recall 22.1
# 720 events threshold 94.4 precision 32.5 recall 22.4
# 735 events threshold 93.6 precision 32.1 recall 22.6
# 750 events threshold 92.4 precision 31.4 recall 22.6
# 765 events threshold 90.9 precision 30.9 recall 22.7
# 780 events threshold 90.0 precision 30.5 recall 22.8
# 795 events threshold 88.9 precision 30.0 recall 22.8
# 810 events threshold 88.2 precision 29.6 recall 22.9
# 825 events threshold 87.0 precision 29.1 recall 22.9
# 840 events threshold 86.2 precision 28.7 recall 23.0
# 855 events threshold 84.9 precision 28.4 recall 23.2
# 870 events threshold 84.2 precision 28.0 recall 23.3
# 885 events threshold 83.4 precision 27.5 recall 23.3
# 900 events threshold 82.4 precision 27.1 recall 23.3
# 915 events threshold 81.7 precision 26.7 recall 23.4
# 930 events threshold 81.2 precision 26.4 recall 23.5
# 945 events threshold 80.8 precision 26.0 recall 23.5
# 960 events threshold 80.2 precision 25.7 recall 23.6
# 975 events threshold 79.4 precision 25.3 recall 23.6
# 990 events threshold 78.7 precision 24.9 recall 23.6
# 1005 events threshold 78.3 precision 24.8 recall 23.8
# 1020 events threshold 77.6 precision 24.4 recall 23.8
# 1035 events threshold 76.9 precision 24.1 recall 23.9
# 1050 events threshold 75.8 precision 23.9 recall 24.0
# 1065 events threshold 75.2 precision 23.5 recall 24.0
# 1080 events threshold 74.3 precision 23.3 recall 24.1
# 1095 events threshold 73.6 precision 23.0 recall 24.1
# 1110 events threshold 73.0 precision 22.7 recall 24.1
# 1125 events threshold 72.2 precision 22.4 recall 24.1
# 1140 events threshold 71.4 precision 22.1 recall 24.1
# 1155 events threshold 70.8 precision 21.9 recall 24.2
# 1170 events threshold 70.2 precision 21.8 recall 24.4
# 1185 events threshold 69.6 precision 21.5 recall 24.4
# 1200 events threshold 69.2 precision 21.2 recall 24.4
# 1215 events threshold 68.8 precision 21.1 recall 24.5
# 1230 events threshold 67.7 precision 20.8 recall 24.5
# 1245 events threshold 67.0 precision 20.5 recall 24.5
# 1260 events threshold 66.1 precision 20.3 recall 24.5
# 1275 events threshold 65.5 precision 20.1 recall 24.6
# 1290 events threshold 64.9 precision 20.1 recall 24.8
# 1305 events threshold 64.3 precision 19.9 recall 24.9
# 1320 events threshold 63.5 precision 19.8 recall 25.0
# 1335 events threshold 62.8 precision 19.5 recall 25.0
# 1350 events threshold 62.2 precision 19.3 recall 25.0
# 1365 events threshold 61.5 precision 19.1 recall 25.0
# 1380 events threshold 60.6 precision 18.9 recall 25.0
# 1395 events threshold 60.0 precision 18.8 recall 25.1
# 1410 events threshold 59.4 precision 18.8 recall 25.3
# 1425 events threshold 58.5 precision 18.6 recall 25.3
# 1440 events threshold 57.7 precision 18.4 recall 25.3
# 1455 events threshold 57.1 precision 18.2 recall 25.3
# 1470 events threshold 56.7 precision 18.1 recall 25.4
# 1485 events threshold 55.8 precision 17.9 recall 25.4
# 1500 events threshold 55.2 precision 17.7 recall 25.4
# 1515 events threshold 54.8 precision 17.7 recall 25.6
# 1530 events threshold 54.0 precision 17.5 recall 25.6
# 1545 events threshold 53.4 precision 17.3 recall 25.6
# 1560 events threshold 52.8 precision 17.2 recall 25.6
# 1575 events threshold 51.8 precision 17.0 recall 25.6
# 1590 events threshold 50.6 precision 17.0 recall 25.8
# 1605 events threshold 50.1 precision 16.9 recall 26.0
# 1620 events threshold 49.0 precision 16.8 recall 26.1
# 1635 events threshold 48.1 precision 16.7 recall 26.2
# 1650 events threshold 47.5 precision 16.8 recall 26.6
# 1665 events threshold 46.1 precision 16.7 recall 26.6
# 1680 events threshold 45.2 precision 16.6 recall 26.7
# 1695 events threshold 44.5 precision 16.6 recall 27.0
# 1710 events threshold 43.9 precision 16.7 recall 27.2
# 1725 events threshold 43.1 precision 16.6 recall 27.4
# 1740 events threshold 42.4 precision 16.6 recall 27.6
# 1755 events threshold 41.2 precision 16.5 recall 27.7
# 1770 events threshold 40.2 precision 16.5 recall 27.9
# 1785 events threshold 39.0 precision 16.6 recall 28.4
# 1800 events threshold 37.8 precision 16.5 recall 28.4
# 1815 events threshold 36.5 precision 16.5 recall 28.6
# 1830 events threshold 35.1 precision 16.5 recall 29.0
# 1845 events threshold 34.0 precision 16.4 recall 29.0
# 1860 events threshold 32.9 precision 16.3 recall 29.0
# 1875 events threshold 32.1 precision 16.3 recall 29.2
# 1890 events threshold 30.7 precision 16.1 recall 29.2
# 1905 events threshold 29.3 precision 16.1 recall 29.3
# 1920 events threshold 27.6 precision 16.0 recall 29.3
# 1935 events threshold 26.4 precision 16.0 recall 29.5
# 1950 events threshold 25.0 precision 15.9 recall 29.6
# 1965 events threshold 22.8 precision 15.9 recall 29.8
# 1980 events threshold 21.1 precision 15.8 recall 29.9
# 1995 events threshold 19.0 precision 15.7 recall 29.9
# 2010 events threshold 16.9 precision 15.7 recall 30.1
# 2025 events threshold 12.6 precision 15.6 recall 30.2
# 2040 events threshold 7.9 precision 15.6 recall 30.4
# 2055 events threshold 0.1 precision 15.5 recall 30.4
# 0 events threshold 2728.4 precision 100.0 recall 0.1
# 15 events threshold 1327.5 precision 100.0 recall 1.5
# 30 events threshold 1039.2 precision 93.5 recall 2.8
# 45 events threshold 733.4 precision 91.3 recall 4.0
# 60 events threshold 674.9 precision 90.2 recall 5.3
# 75 events threshold 612.2 precision 86.8 recall 6.3
# 90 events threshold 544.0 precision 85.7 recall 7.5
# 105 events threshold 498.6 precision 84.9 recall 8.6
# 120 events threshold 474.6 precision 85.1 recall 9.8
# 135 events threshold 441.4 precision 83.8 recall 10.9
# 150 events threshold 398.8 precision 79.5 recall 11.5
# 165 events threshold 347.9 precision 77.1 recall 12.2
# 180 events threshold 324.4 precision 75.1 recall 13.0
# 195 events threshold 293.3 precision 71.9 recall 13.5
# 210 events threshold 277.8 precision 71.6 recall 14.4
# 225 events threshold 264.4 precision 69.5 recall 15.0
# 240 events threshold 248.1 precision 67.2 recall 15.5
# 255 events threshold 234.8 precision 65.6 recall 16.1
# 270 events threshold 220.2 precision 63.8 recall 16.5
# 285 events threshold 211.7 precision 62.9 recall 17.2
# 300 events threshold 201.6 precision 61.5 recall 17.7
# 315 events threshold 193.9 precision 59.5 recall 18.0
# 330 events threshold 188.6 precision 57.4 recall 18.2
# 345 events threshold 179.5 precision 54.9 recall 18.2
# 360 events threshold 173.5 precision 53.2 recall 18.4
# 375 events threshold 166.7 precision 51.6 recall 18.5
# 390 events threshold 162.1 precision 50.9 recall 19.0
# 405 events threshold 154.7 precision 49.0 recall 19.0
# 420 events threshold 149.9 precision 47.5 recall 19.1
# 435 events threshold 147.0 precision 46.3 recall 19.3
# 450 events threshold 143.1 precision 45.2 recall 19.5
# 465 events threshold 139.6 precision 44.0 recall 19.6
# 480 events threshold 135.6 precision 43.0 recall 19.8
# 495 events threshold 132.6 precision 42.5 recall 20.2
# 510 events threshold 129.8 precision 41.9 recall 20.5
# 525 events threshold 127.2 precision 41.3 recall 20.7
# 540 events threshold 124.1 precision 40.5 recall 20.9
# 555 events threshold 121.6 precision 39.6 recall 21.0
# 570 events threshold 117.9 precision 38.5 recall 21.0
# 585 events threshold 116.7 precision 38.1 recall 21.3
# 600 events threshold 113.8 precision 37.4 recall 21.5
# 615 events threshold 111.3 precision 36.7 recall 21.6
# 630 events threshold 109.1 precision 36.0 recall 21.7
# 645 events threshold 106.8 precision 35.1 recall 21.7
# 660 events threshold 105.5 precision 34.5 recall 21.8
# 675 events threshold 103.4 precision 34.3 recall 22.2
# 690 events threshold 101.9 precision 33.6 recall 22.2
# 705 events threshold 100.0 precision 33.1 recall 22.4
# 720 events threshold 98.6 precision 32.7 recall 22.6
# 735 events threshold 97.5 precision 32.2 recall 22.7
# 750 events threshold 96.5 precision 31.6 recall 22.7
# 765 events threshold 95.0 precision 31.5 recall 23.0
# 780 events threshold 94.1 precision 31.1 recall 23.2
# 795 events threshold 93.5 precision 30.8 recall 23.4
# 810 events threshold 92.4 precision 30.3 recall 23.5
# 825 events threshold 91.1 precision 29.9 recall 23.6
# 840 events threshold 90.0 precision 29.4 recall 23.6
# 855 events threshold 89.0 precision 29.2 recall 23.9
# 870 events threshold 88.3 precision 28.8 recall 24.0
# 885 events threshold 87.2 precision 28.4 recall 24.1
# 900 events threshold 86.4 precision 28.1 recall 24.2
# 915 events threshold 85.6 precision 27.6 recall 24.2
# 930 events threshold 84.3 precision 27.4 recall 24.4
# 945 events threshold 83.5 precision 27.0 recall 24.4
# 960 events threshold 82.7 precision 26.5 recall 24.4
# 975 events threshold 81.9 precision 26.1 recall 24.4
# 990 events threshold 81.3 precision 25.9 recall 24.6
# 1005 events threshold 80.9 precision 25.5 recall 24.6
# 1020 events threshold 80.3 precision 25.2 recall 24.6
# 1035 events threshold 79.6 precision 24.9 recall 24.7
# 1050 events threshold 78.8 precision 24.6 recall 24.8
# 1065 events threshold 78.5 precision 24.3 recall 24.8
# 1080 events threshold 78.0 precision 24.1 recall 25.0
# 1095 events threshold 77.2 precision 23.9 recall 25.0
# 1110 events threshold 76.6 precision 23.7 recall 25.1
# 1125 events threshold 75.8 precision 23.6 recall 25.4
# 1140 events threshold 75.2 precision 23.3 recall 25.4
# 1155 events threshold 74.6 precision 23.2 recall 25.6
# 1170 events threshold 73.8 precision 23.0 recall 25.7
# 1185 events threshold 73.3 precision 22.7 recall 25.7
# 1200 events threshold 72.5 precision 22.4 recall 25.7
# 1215 events threshold 71.8 precision 22.1 recall 25.7
# 1230 events threshold 71.2 precision 21.9 recall 25.7
# 1245 events threshold 70.7 precision 21.7 recall 25.8
# 1260 events threshold 70.1 precision 21.5 recall 25.9
# 1275 events threshold 69.6 precision 21.3 recall 26.0
# 1290 events threshold 69.2 precision 21.1 recall 26.0
# 1305 events threshold 68.8 precision 20.9 recall 26.1
# 1320 events threshold 67.9 precision 20.7 recall 26.1
# 1335 events threshold 67.2 precision 20.4 recall 26.1
# 1350 events threshold 66.5 precision 20.2 recall 26.1
# 1365 events threshold 65.8 precision 20.0 recall 26.1
# 1380 events threshold 65.3 precision 19.8 recall 26.1
# 1395 events threshold 64.6 precision 19.7 recall 26.3
# 1410 events threshold 63.8 precision 19.6 recall 26.5
# 1425 events threshold 63.1 precision 19.4 recall 26.5
# 1440 events threshold 62.7 precision 19.2 recall 26.5
# 1455 events threshold 62.2 precision 19.1 recall 26.6
# 1470 events threshold 61.6 precision 18.9 recall 26.6
# 1485 events threshold 60.9 precision 18.7 recall 26.6
# 1500 events threshold 60.1 precision 18.6 recall 26.7
# 1515 events threshold 59.7 precision 18.5 recall 26.8
# 1530 events threshold 59.2 precision 18.4 recall 27.0
# 1545 events threshold 58.3 precision 18.3 recall 27.1
# 1560 events threshold 57.7 precision 18.1 recall 27.1
# 1575 events threshold 57.2 precision 18.0 recall 27.1
# 1590 events threshold 56.8 precision 17.9 recall 27.2
# 1605 events threshold 56.3 precision 17.7 recall 27.2
# 1620 events threshold 55.4 precision 17.5 recall 27.2
# 1635 events threshold 54.9 precision 17.5 recall 27.3
# 1650 events threshold 54.2 precision 17.3 recall 27.3
# 1665 events threshold 53.8 precision 17.2 recall 27.3
# 1680 events threshold 53.4 precision 17.1 recall 27.4
# 1695 events threshold 52.5 precision 16.9 recall 27.4
# 1710 events threshold 51.7 precision 16.8 recall 27.4
# 1725 events threshold 50.6 precision 16.7 recall 27.6
# 1740 events threshold 50.0 precision 16.7 recall 27.7
# 1755 events threshold 49.2 precision 16.6 recall 27.9
# 1770 events threshold 48.6 precision 16.5 recall 28.0
# 1785 events threshold 47.9 precision 16.5 recall 28.1
# 1800 events threshold 47.3 precision 16.5 recall 28.4
# 1815 events threshold 46.4 precision 16.4 recall 28.4
# 1830 events threshold 45.7 precision 16.2 recall 28.4
# 1845 events threshold 44.7 precision 16.2 recall 28.6
# 1860 events threshold 44.3 precision 16.2 recall 28.9
# 1875 events threshold 43.7 precision 16.2 recall 29.1
# 1890 events threshold 43.0 precision 16.2 recall 29.3
# 1905 events threshold 42.5 precision 16.2 recall 29.4
# 1920 events threshold 41.4 precision 16.0 recall 29.4
# 1935 events threshold 40.6 precision 16.0 recall 29.6
# 1950 events threshold 40.0 precision 16.0 recall 29.8
# 1965 events threshold 38.8 precision 16.1 recall 30.2
# 1980 events threshold 38.2 precision 16.0 recall 30.2
# 1995 events threshold 36.8 precision 15.9 recall 30.3
# 2010 events threshold 35.6 precision 15.9 recall 30.5
# 2025 events threshold 34.6 precision 15.8 recall 30.7
# 2040 events threshold 33.6 precision 15.7 recall 30.7
# 2055 events threshold 32.8 precision 15.6 recall 30.7
# 2070 events threshold 32.0 precision 15.5 recall 30.8
# 2085 events threshold 30.8 precision 15.4 recall 30.8
# 2100 events threshold 29.5 precision 15.3 recall 30.8
# 2115 events threshold 28.5 precision 15.3 recall 31.0
# 2130 events threshold 27.2 precision 15.3 recall 31.1
# 2145 events threshold 25.8 precision 15.2 recall 31.2
# 2160 events threshold 24.6 precision 15.1 recall 31.3
# 2175 events threshold 22.8 precision 15.1 recall 31.5
# 2190 events threshold 21.4 precision 15.0 recall 31.5
# 2205 events threshold 19.7 precision 14.9 recall 31.5
# 2220 events threshold 17.2 precision 14.9 recall 31.5
# 2235 events threshold 14.8 precision 14.8 recall 31.6
# 2250 events threshold 11.5 precision 14.7 recall 31.6
# 2265 events threshold 6.1 precision 14.7 recall 31.8
# 2280 events threshold 0.0 precision 14.6 recall 31.8
# 2295 events threshold 0.0 precision 14.7 recall 32.2
# 2310 events threshold 0.0 precision 14.6 recall 32.3
# 2325 events threshold 0.0 precision 14.6 recall 32.5
# 2340 events threshold 0.0 precision 14.6 recall 32.7
# 2355 events threshold 0.0 precision 14.6 recall 32.8
# 2370 events threshold 0.0 precision 14.5 recall 32.8
# 2385 events threshold 0.0 precision 14.4 recall 32.9
# 2400 events threshold 0.0 precision 14.4 recall 33.0
# 2415 events threshold 0.0 precision 14.3 recall 33.0
# 2430 events threshold 0.0 precision 14.3 recall 33.2
# 2445 events threshold 0.0 precision 14.2 recall 33.2
# 2460 events threshold 0.0 precision 14.1 recall 33.2
# 2475 events threshold 0.0 precision 14.1 recall 33.3
# 2490 events threshold -56.4 precision 14.0 recall 33.3
# 0 events threshold 739.1 precision 100.0 recall 0.1
# 15 events threshold 352.3 precision 100.0 recall 1.5
# 30 events threshold 255.9 precision 93.5 recall 2.8
# 45 events threshold 221.2 precision 87.0 recall 3.8
# 60 events threshold 198.3 precision 82.0 recall 4.8
# 75 events threshold 178.6 precision 76.3 recall 5.5
# 90 events threshold 164.4 precision 72.5 recall 6.3
# 105 events threshold 156.0 precision 69.8 recall 7.1
# 120 events threshold 149.5 precision 67.8 recall 7.8
# 135 events threshold 138.8 precision 64.7 recall 8.4
# 150 events threshold 128.2 precision 62.9 recall 9.1
# 165 events threshold 122.7 precision 61.4 recall 9.8
# 180 events threshold 118.9 precision 59.1 recall 10.2
# 195 events threshold 115.4 precision 57.1 recall 10.7
# 210 events threshold 109.9 precision 56.4 recall 11.4
# 225 events threshold 106.7 precision 54.9 recall 11.9
# 240 events threshold 103.0 precision 53.9 recall 12.4
# 255 events threshold 99.7 precision 52.3 recall 12.8
# 270 events threshold 97.2 precision 50.9 recall 13.2
# 285 events threshold 94.4 precision 49.3 recall 13.5
# 300 events threshold 92.3 precision 47.2 recall 13.6
# 315 events threshold 90.3 precision 45.6 recall 13.8
# 330 events threshold 88.1 precision 44.1 recall 14.0
# 345 events threshold 86.5 precision 42.5 recall 14.1
# 360 events threshold 85.6 precision 41.8 recall 14.4
# 375 events threshold 83.8 precision 41.8 recall 15.0
# 390 events threshold 81.7 precision 40.4 recall 15.1
# 405 events threshold 80.7 precision 39.2 recall 15.2
# 420 events threshold 78.9 precision 38.2 recall 15.4
# 435 events threshold 78.1 precision 37.2 recall 15.5
# 450 events threshold 76.9 precision 36.4 recall 15.7
# 465 events threshold 75.2 precision 35.6 recall 15.9
# 480 events threshold 73.3 precision 35.1 recall 16.2
# 495 events threshold 72.3 precision 34.3 recall 16.3
# 510 events threshold 70.6 precision 33.7 recall 16.4
# 525 events threshold 69.3 precision 33.1 recall 16.6
# 540 events threshold 68.2 precision 32.3 recall 16.7
# 555 events threshold 66.5 precision 31.5 recall 16.7
# 570 events threshold 65.1 precision 31.3 recall 17.1
# 585 events threshold 64.2 precision 31.6 recall 17.7
# 600 events threshold 62.5 precision 30.9 recall 17.8
# 615 events threshold 61.2 precision 30.5 recall 18.0
# 630 events threshold 59.9 precision 30.0 recall 18.1
# 645 events threshold 59.1 precision 29.6 recall 18.3
# 660 events threshold 57.7 precision 29.7 recall 18.7
# 675 events threshold 56.5 precision 29.4 recall 19.0
# 690 events threshold 55.1 precision 29.2 recall 19.3
# 705 events threshold 53.7 precision 28.9 recall 19.5
# 720 events threshold 51.8 precision 28.3 recall 19.5
# 735 events threshold 50.3 precision 28.5 recall 20.1
# 750 events threshold 48.6 precision 28.4 recall 20.4
# 765 events threshold 46.9 precision 28.1 recall 20.6
# 780 events threshold 44.4 precision 27.9 recall 20.8
# 795 events threshold 43.1 precision 27.8 recall 21.1
# 810 events threshold 40.7 precision 27.5 recall 21.3
# 825 events threshold 37.9 precision 27.2 recall 21.5
# 840 events threshold 34.5 precision 27.2 recall 21.9
# 855 events threshold 32.1 precision 26.9 recall 22.0
# 870 events threshold 29.0 precision 26.5 recall 22.1
# 885 events threshold 24.3 precision 26.1 recall 22.1
# 900 events threshold 19.0 precision 25.6 recall 22.1
# 915 events threshold 11.5 precision 25.3 recall 22.2
# 0 events threshold 776.4 precision 100.0 recall 0.1
# 15 events threshold 445.8 precision 75.0 recall 1.1
# 30 events threshold 302.7 precision 71.0 recall 2.1
# 45 events threshold 241.8 precision 69.6 recall 3.1
# 60 events threshold 193.6 precision 72.1 recall 4.2
# 75 events threshold 181.5 precision 72.4 recall 5.3
# 90 events threshold 169.5 precision 72.5 recall 6.3
# 105 events threshold 151.4 precision 67.9 recall 6.9
# 120 events threshold 143.1 precision 65.3 recall 7.6
# 135 events threshold 136.3 precision 64.0 recall 8.3
# 150 events threshold 129.2 precision 60.9 recall 8.8
# 165 events threshold 125.0 precision 60.2 recall 9.6
# 180 events threshold 120.2 precision 56.9 recall 9.8
# 195 events threshold 113.9 precision 56.1 recall 10.5
# 210 events threshold 110.6 precision 52.1 recall 10.5
# 225 events threshold 106.5 precision 50.9 recall 11.0
# 240 events threshold 103.6 precision 49.8 recall 11.5
# 255 events threshold 100.9 precision 48.0 recall 11.8
# 270 events threshold 98.6 precision 46.1 recall 12.0
# 285 events threshold 95.8 precision 45.1 recall 12.3
# 300 events threshold 94.0 precision 45.2 recall 13.0
# 315 events threshold 91.9 precision 43.4 recall 13.1
# 330 events threshold 88.3 precision 41.4 recall 13.1
# 345 events threshold 85.7 precision 41.0 recall 13.6
# 360 events threshold 83.0 precision 39.9 recall 13.8
# 375 events threshold 81.5 precision 38.8 recall 14.0
# 390 events threshold 80.5 precision 37.3 recall 14.0
# 405 events threshold 79.2 precision 36.7 recall 14.2
# 420 events threshold 76.9 precision 35.6 recall 14.3
# 435 events threshold 75.0 precision 35.1 recall 14.6
# 450 events threshold 73.2 precision 34.1 recall 14.7
# 465 events threshold 71.5 precision 33.5 recall 14.9
# 480 events threshold 70.0 precision 32.4 recall 14.9
# 495 events threshold 68.9 precision 31.5 recall 14.9
# 510 events threshold 66.8 precision 31.1 recall 15.2
# 525 events threshold 65.0 precision 30.6 recall 15.4
# 540 events threshold 63.3 precision 30.5 recall 15.8
# 555 events threshold 61.9 precision 29.9 recall 15.9
# 570 events threshold 60.1 precision 29.4 recall 16.1
# 585 events threshold 57.7 precision 29.2 recall 16.3
# 600 events threshold 56.4 precision 28.6 recall 16.4
# 615 events threshold 54.8 precision 28.2 recall 16.6
# 630 events threshold 53.4 precision 27.7 recall 16.7
# 645 events threshold 50.6 precision 27.7 recall 17.1
# 660 events threshold 48.1 precision 27.8 recall 17.6
# 675 events threshold 46.1 precision 27.7 recall 17.9
# 690 events threshold 44.5 precision 27.8 recall 18.4
# 705 events threshold 42.5 precision 27.8 recall 18.7
# 720 events threshold 40.0 precision 27.5 recall 18.9
# 735 events threshold 37.4 precision 27.4 recall 19.3
# 750 events threshold 34.6 precision 27.2 recall 19.5
# 765 events threshold 31.5 precision 26.8 recall 19.6
# 780 events threshold 28.9 precision 26.2 recall 19.6
# 795 events threshold 26.0 precision 25.9 recall 19.7
# 810 events threshold 21.6 precision 25.5 recall 19.8
# 825 events threshold 17.9 precision 25.2 recall 19.9
# 840 events threshold -19.6 precision 25.1 recall 20.2
# 0 events threshold 705.5 precision 100.0 recall 0.1
# 15 events threshold 407.8 precision 93.8 recall 1.4
# 30 events threshold 301.4 precision 87.1 recall 2.6
# 45 events threshold 231.4 precision 78.3 recall 3.4
# 60 events threshold 200.3 precision 77.0 recall 4.5
# 75 events threshold 181.0 precision 75.0 recall 5.4
# 90 events threshold 169.6 precision 71.4 recall 6.2
# 105 events threshold 159.2 precision 70.8 recall 7.2
# 120 events threshold 148.5 precision 70.2 recall 8.1
# 135 events threshold 140.4 precision 66.9 recall 8.7
# 150 events threshold 133.8 precision 64.9 recall 9.4
# 165 events threshold 126.8 precision 62.7 recall 9.9
# 180 events threshold 121.7 precision 60.2 recall 10.4
# 195 events threshold 117.5 precision 58.7 recall 11.0
# 210 events threshold 113.6 precision 56.9 recall 11.5
# 225 events threshold 110.4 precision 56.6 recall 12.2
# 240 events threshold 106.8 precision 53.9 recall 12.4
# 255 events threshold 104.5 precision 52.0 recall 12.7
# 270 events threshold 99.8 precision 50.6 recall 13.1
# 285 events threshold 97.3 precision 49.7 recall 13.6
# 300 events threshold 94.1 precision 48.8 recall 14.1
# 315 events threshold 91.9 precision 47.5 recall 14.3
# 330 events threshold 90.3 precision 46.2 recall 14.6
# 345 events threshold 88.6 precision 45.1 recall 14.9
# 360 events threshold 86.7 precision 43.8 recall 15.1
# 375 events threshold 84.7 precision 43.4 recall 15.6
# 390 events threshold 83.1 precision 41.7 recall 15.6
# 405 events threshold 80.9 precision 40.9 recall 15.9
# 420 events threshold 79.2 precision 40.6 recall 16.3
# 435 events threshold 77.9 precision 39.4 recall 16.4
# 450 events threshold 76.3 precision 38.4 recall 16.5
# 465 events threshold 75.0 precision 37.1 recall 16.5
# 480 events threshold 73.2 precision 36.2 recall 16.6
# 495 events threshold 71.0 precision 35.5 recall 16.8
# 510 events threshold 70.2 precision 34.6 recall 16.9
# 525 events threshold 68.7 precision 34.0 recall 17.1
# 540 events threshold 67.2 precision 33.3 recall 17.2
# 555 events threshold 66.0 precision 32.7 recall 17.4
# 570 events threshold 64.9 precision 32.2 recall 17.6
# 585 events threshold 63.0 precision 31.7 recall 17.8
# 600 events threshold 61.7 precision 31.1 recall 17.9
# 615 events threshold 59.7 precision 30.7 recall 18.1
# 630 events threshold 57.5 precision 30.3 recall 18.3
# 645 events threshold 56.0 precision 29.7 recall 18.4
# 660 events threshold 55.0 precision 29.2 recall 18.5
# 675 events threshold 53.6 precision 29.3 recall 18.9
# 690 events threshold 52.4 precision 29.2 recall 19.3
# 705 events threshold 51.0 precision 29.0 recall 19.6
# 720 events threshold 49.8 precision 29.0 recall 20.0
# 735 events threshold 47.8 precision 28.7 recall 20.2
# 750 events threshold 45.8 precision 28.5 recall 20.5
# 765 events threshold 44.0 precision 28.2 recall 20.7
# 780 events threshold 42.5 precision 27.8 recall 20.7
# 795 events threshold 40.7 precision 27.5 recall 20.9
# 810 events threshold 38.7 precision 27.4 recall 21.2
# 825 events threshold 36.2 precision 27.0 recall 21.3
# 840 events threshold 33.7 precision 26.6 recall 21.4
# 855 events threshold 30.9 precision 26.2 recall 21.4
# 870 events threshold 28.4 precision 25.8 recall 21.5
# 885 events threshold 24.2 precision 25.6 recall 21.7
# 900 events threshold 20.0 precision 25.4 recall 21.9
# 915 events threshold 11.6 precision 25.0 recall 21.9
# 930 events threshold -1.0 precision 24.6 recall 21.9
# 0 events threshold 0.0 precision 100.0 recall 0.1
# 15 events threshold 0.0 precision 75.0 recall 1.1
# 30 events threshold 0.0 precision 77.4 recall 2.3
# 45 events threshold 0.0 precision 78.3 recall 3.4
# 60 events threshold 0.0 precision 73.8 recall 4.3
# 75 events threshold 0.0 precision 68.4 recall 5.0
# 90 events threshold 0.0 precision 64.8 recall 5.6
# 105 events threshold 0.0 precision 63.2 recall 6.4
# 120 events threshold 0.0 precision 62.8 recall 7.3
# 135 events threshold 0.0 precision 61.8 recall 8.0
# 150 events threshold 0.0 precision 62.3 recall 9.0
# 165 events threshold 0.0 precision 59.6 recall 9.5
# 180 events threshold 0.0 precision 59.1 recall 10.2
# 195 events threshold 0.0 precision 56.6 recall 10.6
# 210 events threshold 0.0 precision 55.0 recall 11.1
# 225 events threshold 0.0 precision 54.4 recall 11.8
# 240 events threshold 0.0 precision 52.7 recall 12.1
# 255 events threshold 0.0 precision 50.0 recall 12.2
# 270 events threshold 0.0 precision 50.6 recall 13.1
# 285 events threshold 0.0 precision 49.0 recall 13.4
# 300 events threshold 0.0 precision 47.5 recall 13.7
# 315 events threshold 0.0 precision 47.2 recall 14.2
# 330 events threshold 0.0 precision 45.6 recall 14.4
# 345 events threshold 0.0 precision 45.4 recall 15.0
# 360 events threshold 0.0 precision 44.9 recall 15.5
# 375 events threshold 0.0 precision 44.1 recall 15.9
# 390 events threshold 0.0 precision 43.5 recall 16.3
# 405 events threshold 0.0 precision 42.6 recall 16.5
# 420 events threshold 0.0 precision 42.3 recall 17.0
# 435 events threshold 0.0 precision 41.7 recall 17.4
# 450 events threshold 0.0 precision 41.5 recall 17.9
# 465 events threshold 0.0 precision 40.3 recall 18.0
# 480 events threshold 0.0 precision 40.1 recall 18.5
# 0 events threshold 449.3 precision 0.0 recall 0.0
# 15 events threshold 274.2 precision 87.5 recall 1.3
# 30 events threshold 222.8 precision 93.5 recall 2.8
# 45 events threshold 193.8 precision 93.5 recall 4.1
# 60 events threshold 177.1 precision 95.1 recall 5.5
# 75 events threshold 157.5 precision 93.4 recall 6.8
# 90 events threshold 145.0 precision 93.4 recall 8.1
# 105 events threshold 130.9 precision 88.7 recall 9.0
# 120 events threshold 120.3 precision 85.1 recall 9.8
# 135 events threshold 112.6 precision 82.4 recall 10.7
# 150 events threshold 101.8 precision 81.5 recall 11.8
# 165 events threshold 96.9 precision 77.1 recall 12.2
# 180 events threshold 89.0 precision 75.1 recall 13.0
# 195 events threshold 84.0 precision 71.4 recall 13.4
# 210 events threshold 78.1 precision 69.7 recall 14.1
# 225 events threshold 74.4 precision 68.6 recall 14.8
# 240 events threshold 71.4 precision 66.0 recall 15.2
# 255 events threshold 68.1 precision 63.3 recall 15.5
# 270 events threshold 62.7 precision 60.9 recall 15.8
# 285 events threshold 59.5 precision 58.7 recall 16.1
# 300 events threshold 57.2 precision 56.8 recall 16.3
# 315 events threshold 53.7 precision 54.7 recall 16.5
# 330 events threshold 50.4 precision 53.2 recall 16.8
# 345 events threshold 48.3 precision 51.4 recall 17.0
# 360 events threshold 46.7 precision 49.6 recall 17.1
# 375 events threshold 44.3 precision 48.4 recall 17.4
# 390 events threshold 40.9 precision 46.5 recall 17.4
# 405 events threshold 37.8 precision 45.3 recall 17.6
# 420 events threshold 35.0 precision 43.9 recall 17.7
# 435 events threshold 32.4 precision 42.9 recall 17.9
# 450 events threshold 30.3 precision 41.5 recall 17.9
# 465 events threshold 27.2 precision 40.3 recall 18.0
# 480 events threshold 21.8 precision 39.1 recall 18.0
# 495 events threshold 12.5 precision 37.9 recall 18.0

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import matplotlib.ticker as mtick

import seaborn as sns

blue, green, red, purple = sns.color_palette()[:4]

sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig = plt.figure(figsize=(10, 6))
axes = fig.add_subplot(111)


axes.plot(sigvisa_withhf_precs, sigvisa_withhf_recalls, label="Sigvisa (merged)", 
          color=green, alpha=0.8, ls='-', lw=3)

#axes.plot(sigvisa_precs, sigvisa_recalls, label="Sigvisa (merged)", color=green, alpha=1.0, lw=3, ls='-')


axes.plot(sigvisa_seed1_precs, sigvisa_seed1_recalls, color=green, label="Sigvisa (0.8-4.5hz)", alpha=0.8, ls=':')
axes.plot(sigvisa_seed2_precs, sigvisa_seed2_recalls, color=green, alpha=0.8, ls=':')
axes.plot(sigvisa_seed3_precs, sigvisa_seed3_recalls, color=green, alpha=0.8, ls=':')

axes.plot(sigvisa_hf11_precs, sigvisa_hf11_recalls, color=green, label="Sigvisa (2.0-4.5hz)", alpha=0.8, ls='-.')
sigvisa_hf12_precs_hack, sigvisa_hf12_recalls_hack = zip(*[(p, r) for (p, r) in zip(sigvisa_hf12_precs, sigvisa_hf12_recalls) if p > 0])
axes.plot(sigvisa_hf12_precs_hack, sigvisa_hf12_recalls_hack, color=green, alpha=0.8, ls='-.')


axes.plot(netvisa_precs, netvisa_recalls, label="Netvisa", color=blue, lw=3, ls='--')


#axes.scatter(thresh_precision, thresh_recall, marker="^", s=100, color="orange", label="Sigvisa (125)")
axes.scatter(leb_precision, leb_recall, marker="*", s=100, color=red, label="LEB")
axes.scatter(sel3_precision, sel3_recall, marker="d", s=100, color=purple, label="SEL3")

axes.set_xlabel("Precision")
axes.set_ylabel("Recall")
axes.set_xlim((0, 100))
axes.set_ylim((0, 35))


axes.legend(loc="upper right")


fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
yticks = mtick.FormatStrFormatter(fmt)
axes.yaxis.set_major_formatter(yticks)
_ = axes.xaxis.set_major_formatter(yticks)

# %%
print sigvisa_withhf_precs
# Out:
# [100.0, 100.0, 93.54838709677419, 91.30434782608695, 90.1639344262295, 86.84210526315789, 85.71428571428571, 84.90566037735849, 85.12396694214875, 83.82352941176471, 79.47019867549669, 77.10843373493977, 75.13812154696133, 71.93877551020408, 71.56398104265404, 69.46902654867256, 67.21991701244814, 65.625, 63.837638376383765, 62.93706293706294, 61.461794019933556, 59.49367088607595, 57.40181268882175, 54.91329479768786, 53.18559556786703, 51.59574468085106, 50.89514066496164, 49.01477832512315, 47.50593824228029, 46.330275229357795, 45.23281596452328, 43.99141630901288, 43.03534303534303, 42.54032258064516, 41.87866927592955, 41.254752851711025, 40.48059149722736, 39.568345323741006, 38.52889667250438, 38.05460750853242, 37.437603993344425, 36.688311688311686, 35.97464342313788, 35.139318885448915, 34.49319213313162, 34.319526627218934, 33.57452966714906, 33.14447592067989, 32.73231622746186, 32.20108695652174, 31.55792276964048, 31.4621409921671, 31.11395646606914, 30.77889447236181, 30.33292231812577, 29.90314769975787, 29.369797859690845, 29.205607476635514, 28.817451205510906, 28.442437923250566, 28.079911209766927, 27.62008733624454, 27.389903329752954, 26.955602536997887, 26.534859521331946, 26.12704918032787, 25.93340060544904, 25.54671968190855, 25.171400587659157, 24.903474903474905, 24.643196955280686, 24.296435272045027, 24.14431082331175, 23.905109489051096, 23.672367236723673, 23.623445825932503, 23.312883435582823, 23.18339100346021, 22.971818958155424, 22.681281618887017, 22.398001665278933, 22.12171052631579, 21.852152721364742, 21.669341894060995, 21.49088025376685, 21.316614420062695, 21.06893880712626, 20.903522205206738, 20.666161998485997, 20.434131736526947, 20.207253886010363, 19.98535871156662, 19.768283852280955, 19.69914040114613, 19.631467044649185, 19.424964936886397, 19.222761970853576, 19.093406593406595, 18.898708361658734, 18.70794078061911, 18.58760826115923, 18.46965699208443, 18.419333768778575, 18.30530401034929, 18.129404228058938, 17.956852791878173, 17.850408548082967, 17.68368617683686, 17.520049352251696, 17.48166259168704, 17.322834645669293, 17.16686674669868, 17.073170731707318, 16.922169811320753, 16.773816481589712, 16.743916570104286, 16.65709362435382, 16.62870159453303, 16.544325239977415, 16.461366181410973, 16.49083842309828, 16.354625550660792, 16.220644456581102, 16.197183098591548, 16.227834497581945, 16.204690831556505, 16.181914331041778, 16.1594963273872, 16.03331598125976, 16.012396694214875, 15.991799077396207, 16.07324516785351, 15.951539626451288, 15.881763527054108, 15.862754848334163, 15.844027640671273, 15.727584517393435, 15.61284046692607, 15.548044422984066, 15.436241610738255, 15.32603522132318, 15.311909262759924, 15.251055842327546, 15.191053122087604, 15.131883387320684, 15.119485294117647, 15.015974440894569, 14.913871260199455, 14.85817199459703, 14.803220035778175, 14.704575744113727, 14.6954986760812, 14.598860149057431, 14.677700348432056, 14.625703158805711, 14.617368873602752, 14.60914139256728, 14.558573853989813, 14.466469843947701, 14.417435037720033, 14.369012911286964, 14.27980132450331, 14.273961332784863, 14.18642681929681, 14.099959366111337, 14.054927302100161, 13.970293054997994]

# %% [markdown]
# ## Sigvisa variants prec/recall

# %% [markdown]
# ## All methods prec/recall

# %% [markdown]
# ## Location errors

# %%
import seaborn as sns

import pandas as pd

basedir = "/home/dmoore/python/sigvisa/notebooks/thesis/results/"
errs = {}
errs["Netvisa"] = netvisa_errors
errs["LEB"] = leb_errors
errs["SEL3"] = sel3_errors
errs["Sigvisa"] = sigvisa_withhf_errors

max_len = np.max([len(x) for x in errs.values()])
padded = {k : np.concatenate((errs[k], np.ones(max_len - len(errs[k]))*np.nan )) for k in errs.keys()}

d = pd.DataFrame(padded)

# %%
fig = plt.figure(figsize=(8, 5))
axes = fig.add_subplot(111)
order=["SEL3", "Netvisa", "Sigvisa", "LEB"]

# permute colors to match above precision-recall plot
palette = sns.color_palette()
permuted = (palette[3], palette[0], palette[1], palette[2])

sns.barplot(data=d, order=order, axes=axes, palette=permuted, ci=None)

# label the plot with error values
rects = axes.patches
labels = ["%.0fkm" % np.mean(errs[key]) for key in order]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    axes.text(rect.get_x() + rect.get_width()/2, height + 2, label, ha='center', va='bottom')

axes.set_ylabel("mean location error (km)")
axes.set_ylim([0, 100])
# Out:
# (0, 100)
# (0, 100)

# %%
fig = plt.figure(figsize=(8, 5))
axes = fig.add_subplot(111)
order = ["SEL3", "Netvisa", "Sigvisa", "LEB"]

sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)

# permute colors to match above precision-recall plot
palette = sns.color_palette()
permuted = (palette[3], palette[0], palette[1], palette[2])

sns.set_context("paper", font_scale=1.5)
sns.violinplot(data=d, order=order, palette=permuted, axes=axes, inner="quartile", width=0.9, cut=0)
axes.set_ylabel("location error (km)")

# label the plot with error values
rects = axes.patches
labels = ["%.0fkm" % np.mean(errs[key]) for key in order]
heights = [66, 84, 30, 25]
for i, key in enumerate(order):
    v = np.mean(errs[key])
    m = np.max(errs[key])
    #height = rect.get_height()
    axes.text(i + 0.25, heights[i], "mean\n%.0fkm" % v, ha='center', va='bottom')

axes.set_ylim([0, 250])
# Out:
# (0, 250)
# (0, 250)

# %% [markdown]
# # De Novo events

# %%
from sigvisa.utils.geog import dist_km
import os

basedir = "/home/dmoore/python/sigvisa/notebooks/thesis/results/"

# python results/evaluate_serialized.py  --serialized=cloud/remote_jobs/dn1234/merged.tgz --denovo

sigvisa_denovo_bulletin = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_dn1234.txt"))
leb_denovo_bulletin = np.loadtxt(os.path.join(basedir, "leb_bulletin_dn1234.txt"))
sel3_denovo_bulletin = np.loadtxt(os.path.join(basedir, "sel3_bulletin_dn1234.txt"))
visa_denovo_bulletin = np.loadtxt(os.path.join(basedir, "visa_bulletin_dn1234.txt"))


sigvisa_denovo_thresholded_bulletin = np.asarray([ev for ev in sigvisa_denovo_bulletin if ev[5] > 128.0])

def filter_de_novo(bulletin):
    train_evids = [int(evid) for evid in np.loadtxt("/home/dmoore/python/sigvisa/notebooks/thesis/train_evids.txt")]
    train_evs = [get_event(evid) for evid in train_evids]

    def is_denovo(row, dist_threshold_km=50):
        lon, lat, depth, time, mb = row[:5]
        dists = [dist_km((lon, lat), (tev.lon, tev.lat)) for tev in train_evs]
        return np.min(dists) > dist_threshold_km

    filtered = np.array([row for row in bulletin if is_denovo(row)])
    return filtered

isc_dnperiods_bulletin = np.loadtxt(os.path.join(basedir, "isc_bulletin_dn1234.txt"))
isc_denovo_bulletin = filter_de_novo(isc_dnperiods_bulletin)

# %%
from sigvisa.results.compare import f1_and_error
import pandas as pd

kwargs = {
    'max_delta_deg': 2.0,
    'max_delta_time': 50.0
}

_, _, sigvisa_dn_recall, (sigvisa_dn_meanerr, _), _ = f1_and_error(isc_denovo_bulletin, sigvisa_denovo_bulletin, **kwargs)
_, _, sigvisa_thresh_dn_recall, (sigvisa_thresh_dn_meanerr, _), _ = f1_and_error(isc_denovo_bulletin, sigvisa_denovo_thresholded_bulletin, **kwargs)

_, _, netvisa_dn_recall, (netvisa_dn_meanerr, _), _ = f1_and_error(isc_denovo_bulletin, visa_denovo_bulletin, **kwargs)
_, _, leb_dn_recall, (leb_dn_meanerr, _), _ = f1_and_error(isc_denovo_bulletin, leb_denovo_bulletin, **kwargs)
_, _, sel3_dn_recall, (sel3_dn_meanerr, _), _ = f1_and_error(isc_denovo_bulletin, sel3_denovo_bulletin, **kwargs)

nevents = len(isc_denovo_bulletin)
combined = []
combined.append( ("Netvisa", netvisa_dn_recall, netvisa_dn_recall/100.*nevents, netvisa_dn_meanerr))
combined.append (("LEB", leb_dn_recall, leb_dn_recall/100.*nevents, leb_dn_meanerr))
combined.append (("SEL3", sel3_dn_recall, sel3_dn_recall/100.*nevents, sel3_dn_meanerr))
combined.append  (("Sigvisa (all)", sigvisa_dn_recall, sigvisa_dn_recall/100.*nevents, sigvisa_dn_meanerr))
combined.append  (("Sigvisa (top)", sigvisa_thresh_dn_recall, sigvisa_thresh_dn_recall/100.*nevents, sigvisa_thresh_dn_meanerr))

recalls = dict([(key, recall) for (key, recall, evs, meanerr) in combined])
nevs = dict([(key, evs) for (key, recall, evs, meanerr) in combined])
errs = dict([(key, meanerr) for (key, recall, evs, meanerr) in combined])

d = pd.DataFrame(combined, columns=("System", "Recall", "Events", "Error"))

# %%
import seaborn as sns
import matplotlib.ticker as mtick

order = ["SEL3", "Netvisa", "Sigvisa (top)", "Sigvisa (all)", "LEB"]
# permute colors to match above precision-recall plot
palette = sns.color_palette()
permuted = (palette[3], palette[0], palette[1], palette[4], palette[2])


sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)

fig = plt.figure(figsize=(8, 5))
axes = fig.add_subplot(111)
sns.barplot(x="System", y="Events", data=d, axes=axes, ci=None, 
            order=order, palette=permuted)
axes.set_ylabel("Events detected")
axes.set_xlabel("")

#fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
#yticks = mtick.FormatStrFormatter(fmt)
#axes.yaxis.set_major_formatter(yticks)


# label the plot with error values
rects = axes.patches
#labels = ["%.1f" % recalls[key] for key in order]
labels = ["%d" % nevs[key] for key in order]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    axes.text(rect.get_x() + rect.get_width()/2, height + 0.2, label, ha='center', va='bottom')

axes.set_ylim([0, 14])

fig = plt.figure(figsize=(8, 5))
axes = fig.add_subplot(111)
sns.barplot(x="System", y="Error", data=d, axes=axes, ci=None, 
            order=order, palette=permuted)
axes.set_ylabel("mean location error (km)")
axes.set_xlabel("")


# label the plot with error values
rects = axes.patches
labels = ["%.0fkm" % errs[key] for key in order]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    axes.text(rect.get_x() + rect.get_width()/2, height + 2, label, ha='center', va='bottom')

# %%
# analyze Sigvisa denovo events not in LEB

indices_sv = find_matching(isc_denovo_bulletin, sigvisa_denovo_bulletin, **kwargs)
indices_leb = find_matching(isc_denovo_bulletin, leb_denovo_bulletin, **kwargs)

matched_leb = [i for (i,j) in indices_leb]

s = Sigvisa()

new_sigvisa_orids = []
for (i,j) in indices_sv:
    if i not in matched_leb:
        print isc_denovo_bulletin[i]
        print sigvisa_denovo_bulletin[j]
        print
        isc_orid = isc_denovo_bulletin[i,6]
        orid = s.sql("select orid from sigvisa_origin where matched_isc_orid=%d" % isc_orid)[0][0]
        new_sigvisa_orids.append(orid)
        
print new_sigvisa_orids
# Out:
# [ -1.13916400e+02   3.50155000e+01   7.50000000e+00   1.20060721e+09
#    2.90000000e+00   0.00000000e+00   1.04890600e+06]
# [ -1.13914428e+02   3.51845690e+01   5.66568192e+00   1.20060722e+09
#    3.31066972e+00   1.18500239e+02]
#
# [ -1.19966000e+02   3.93090000e+01   1.26000000e+01   1.20155871e+09
#    3.00000000e+00   0.00000000e+00   4.22318000e+05]
# [ -1.19214089e+02   3.86024556e+01   2.14905846e+00   1.20155875e+09
#    3.30323694e+00   1.39761870e+02]
#
# [ -1.05470000e+02   3.92750000e+01   2.00000000e+00   1.20406895e+09
#    2.90000000e+00   0.00000000e+00   1.52368600e+06]
# [ -1.04447041e+02   3.90922069e+01   8.14599734e+00   1.20406895e+09
#    3.12393330e+00   4.31492330e+01]
#
# [ -1.19979500e+02   3.95228000e+01   1.00000000e+01   1.20497082e+09
#    3.40000000e+00   0.00000000e+00   3.90254000e+06]
# [ -1.19787347e+02   3.95983371e+01   7.52909315e-01   1.20497082e+09
#    2.92590203e+00   2.24634654e+02]
#
# [ -1.20282000e+02   3.95890000e+01   1.41000000e+01   1.20543097e+09
#    2.90000000e+00   0.00000000e+00   5.79518000e+05]
# [ -1.20745165e+02   3.99015952e+01   8.32730046e+00   1.20543097e+09
#    2.92482994e+00   9.90081895e+01]
#
# [ -1.20279000e+02   3.95890000e+01   9.80000000e+00   1.20543098e+09
#    3.10000000e+00   0.00000000e+00   5.79520000e+05]
# [ -1.19672948e+02   4.00024235e+01   2.01585469e+00   1.20543098e+09
#    2.88643731e+00   1.91639363e+02]
#
# [ -1.19936000e+02   3.95320000e+01   1.70000000e+00   1.20658933e+09
#    3.20000000e+00   0.00000000e+00   5.80932000e+05]
# [ -1.21162941e+02   3.98510688e+01   7.04455088e+00   1.20658931e+09
#    3.28619096e+00   3.63579445e+01]
#
# [2102L, 2156L, 2215L, 2233L, 2243L, 2244L, 2279L]

# %% [markdown]
# # Detection probability by magnitude

# %%
# bin isc events by magnitude
# within each magnitude bin, report probability of detection by each other system

import os
from sigvisa.results.compare import f1_and_error, find_matching
import pandas as pd

basedir = "/home/dmoore/python/sigvisa/notebooks/thesis/results/"

#isc_bulletin = np.loadtxt(os.path.join(basedir, "isc_bulletin.txt"))
#netvisa_bulletin = np.loadtxt(os.path.join(basedir, "visa_bulletin_visa.txt"))
#sel3_bulletin = np.loadtxt(os.path.join(basedir, "sel3_bulletin_sel3.txt"))
#leb_bulletin = np.loadtxt(os.path.join(basedir, "leb_bulletin_leb.txt"))
#sigvisa_bulletin_merged = np.loadtxt(os.path.join(basedir, "sigvisa_bulletin_seed123_sum.txt"))
#sigvisa_bulletin_125 = np.asarray([row for row in sigvisa_bulletin_merged if row[5] > 125])



match_delta_deg=2.0
match_delta_s=50.0

truth = isc_wells_mb_bulletin

bulletins = {}
bulletins['Netvisa'] = netvisa_bulletin
bulletins['Sigvisa (top)'] = sigvisa_thresholded 
bulletins['Sigvisa (all)'] = sigvisa_bulletin_merged_123hf
bulletins['SEL3'] = sel3_bulletin
bulletins['LEB'] = leb_bulletin

mb_bins_left = (1.0, 2.0, 2.5, 3.0, 3.5, 4.0,  np.inf)

#scores_by_bin = pd.DataFrame()

def filter_bulletin(bulletin, min_mb, max_mb):
    return 

results = []

for i in range(len(mb_bins_left) - 1):
    min_mb = mb_bins_left[i]
    max_mb = mb_bins_left[i+1]
    
    filter_isc = np.asarray([row for row in truth if row[4] > min_mb and row[4] < max_mb])
    binstr = "%.1f-%.1f" % (min_mb, max_mb) if max_mb < np.inf else "%.1f+" % min_mb
    for key, bulletin in bulletins.items():
        f, p, r, err, errs = f1_and_error(filter_isc, bulletin, 
                                          max_delta_deg=match_delta_deg, 
                                          max_delta_time=match_delta_s)
        results.append((key, binstr, r, int(r/100. * len(filter_isc))))
results = pd.DataFrame(data=results, columns=("Bulletin", "bin", "recall", "evs"))

# %%
indices_sv = find_matching(filter_isc, bulletins["Sigvisa (all)"], max_delta_deg=match_delta_deg, max_delta_time=match_delta_s)
print indices_sv
# Out:
# [(0, 370), (1, 704), (2, 1285)]

# %%
print filter_isc[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-40fd3987d68e> in <module>()
# ----> 1 print filter_isc[3]
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
print filter_isc[2]
print bulletins["Sigvisa (all)"][704]
# Out:
# [ -1.14831800e+02   4.11876000e+01   9.18000000e+00   1.20409918e+09
#    4.06711821e+00   0.00000000e+00   2.36032000e+05]
# [ -1.22770307e+02   3.89291457e+01   6.49511410e+00   1.20383113e+09
#    3.79566945e+00   2.34020950e+02]

# %%
import matplotlib.ticker as mtick


# permute colors to match above precision-recall plot
palette = sns.color_palette()
permuted = (palette[3], palette[0], palette[2], palette[1], palette[4])

sns.set_style("whitegrid")
sns.set_context("talk", font_scale=1.3)
sns.barplot(x="bin", y="recall", hue="Bulletin", 
            hue_order=["SEL3", "Netvisa", "LEB", "Sigvisa (top)", "Sigvisa (all)"], 
            data=results, palette=permuted)
plt.gca().set_ylabel("percentage of gold events detected")
plt.gca().set_xlabel("body-wave magnitude (mb)")

fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
yticks = mtick.FormatStrFormatter(fmt)
plt.gca().yaxis.set_major_formatter(yticks)

# %%
print "hello"
# Out:
# hello

# %%
min_mb = 3.5
max_mb = 4.0
filter_isc = np.asarray([row for row in truth if row[4] > min_mb and row[4] < max_mb])
print filter_isc
# Out:
# [[ -1.05282500e+02   4.36982000e+01   0.00000000e+00   1.20371802e+09
#     3.70000000e+00   0.00000000e+00   3.37543100e+06]
#  [ -1.14871300e+02   4.11625000e+01   1.06000000e+01   1.20380956e+09
#     3.65201394e+00   0.00000000e+00   2.87968000e+05]
#  [ -1.14887700e+02   4.10931000e+01   8.93000000e+00   1.20408718e+09
#     3.53341272e+00   0.00000000e+00   2.86414000e+05]
#  [ -1.14923700e+02   4.11530000e+01   8.13000000e+00   1.20421144e+09
#     3.50799817e+00   0.00000000e+00   2.36336000e+05]
#  [ -1.06852400e+02   4.52005000e+01   0.00000000e+00   1.20421834e+09
#     3.60000000e+00   0.00000000e+00   3.37607200e+06]
#  [ -1.05210700e+02   4.38214000e+01   0.00000000e+00   1.20432836e+09
#     3.70000000e+00   0.00000000e+00   3.37619800e+06]
#  [ -1.05217000e+02   4.37785000e+01   0.00000000e+00   1.20457110e+09
#     3.70000000e+00   0.00000000e+00   3.75261700e+06]
#  [ -1.16850700e+02   3.43091000e+01   1.30000000e+01   1.20476247e+09
#     3.70000000e+00   0.00000000e+00   3.75299200e+06]
#  [ -1.05072700e+02   4.35973000e+01   0.00000000e+00   1.20483750e+09
#     3.90000000e+00   0.00000000e+00   3.75312600e+06]]

# %% [markdown]
# # LEB minus Sigvisa

# %%
# full sigvisa bulletin
indices = find_matching(leb_bulletin, sigvisa_bulletin_merged_123hf, max_delta_deg=match_delta_deg, max_delta_time=match_delta_s)
leb_evs_matched = [i for (i,j) in indices]
notmatched_bulletin = [leb_bulletin[i] for i in range(len(leb_bulletin)) if i not in leb_evs_matched]

for row in notmatched_bulletin:
    lon, lat, depth, time, mb = row[:5]
    print lon, lat, depth, time, mb
# Out:
# -114.74022 41.035096 0.0 1203703473.0 -999.0
# -114.42951 40.860615 0.0 1203748167.0 2.5429521
# -114.85047 41.151386 0.0 1203831780.0 -999.0
# -114.74279 41.160907 0.0 1204445484.0 -999.0

# %%
# full sigvisa bulletin
sigvisa_bulletin_444 = np.asarray([row for row in sigvisa_bulletin_merged_123hf if row[5] > 444])
indices = find_matching(leb_bulletin, sigvisa_bulletin_444, max_delta_deg=match_delta_deg, max_delta_time=match_delta_s)
leb_evs_matched = [i for (i,j) in indices]
notmatched_bulletin = [leb_bulletin[i] for i in range(len(leb_bulletin)) if i not in leb_evs_matched]
for row in notmatched_bulletin:
    lon, lat, depth, time, mb = row[:5]
    print lon, lat, depth, time, mb
# Out:
# -114.92365 41.127744 0.0 1203657221.0 -999.0
# -114.87925 40.851762 0.0 1203668114.0 -999.0
# -114.96731 41.224394 0.0 1203671772.0 -999.0
# -115.25048 41.237505 0.0 1203675783.0 -999.0
# -114.74022 41.035096 0.0 1203703473.0 -999.0
# -114.69307 40.96367 0.0 1203703564.0 -999.0
# -114.97308 41.217925 0.0 1203705968.0 -999.0
# -114.98601 41.244917 0.0 1203707613.0 -999.0
# -115.04058 41.270541 0.0 1203729452.0 -999.0
# -114.42951 40.860615 0.0 1203748167.0 2.5429521
# -115.01475 41.241083 0.0 1203748437.0 2.4373969
# -114.47897 41.066469 0.0 1203752587.0 -999.0
# -114.6916 40.929512 0.0 1203752918.0 -999.0
# -114.88003 41.19095 0.0 1203783024.0 -999.0
# -114.63588 40.991008 0.0 1203809954.0 -999.0
# -115.0 41.174325 0.0 1203828378.0 -999.0
# -122.63993 38.850411 0.0 1203831132.0 3.8220426
# -114.85047 41.151386 0.0 1203831780.0 -999.0
# -114.66059 41.133279 0.0 1203899119.0 -999.0
# -114.83112 41.153632 0.0 1203903746.0 -999.0
# -114.79676 41.133531 0.0 1203998511.0 -999.0
# -114.78928 41.276576 0.0 1204004370.0 -999.0
# -114.69839 41.090006 0.0 1204119155.0 -999.0
# -114.97517 41.278346 0.0 1204159463.0 2.610207
# -106.43127 44.674521 0.0 1204218335.0 -999.0
# -114.74279 41.160907 0.0 1204445484.0 -999.0
# -114.65122 40.988636 0.0 1204463923.0 -999.0
# -114.74337 40.987364 11.741856 1204644076.0 -999.0

# %% [markdown]
# # Maps

# %%
def map_bulletin(bulletin, true_bulletin, preset="full",
                 stas=None, region_args=None, **kwargs):

    from sigvisa.plotting.event_heatmap import EventHeatmap

    interval=1
    if preset=="full":
        region_args = {'left_lon': -126, 
                       'right_lon': -100,
                      'bottom_lat': 33, 
                       'top_lat': 49}
    elif preset=="wells":
        stas=None
        interval=0.3
        region_args = {'left_lon': -115.4, 
                       'right_lon': -114.5,
                      'bottom_lat': 40.8, 
                       'top_lat': 41.5}
        
    elif preset=="btm":
        stas=None
        interval=1
        region_args = {'left_lon': -107, 
                       'right_lon': -104,
                      'bottom_lat': 43, 
                       'top_lat': 46}
    
    s = Sigvisa()
    hm = EventHeatmap(f=None, calc=False, **region_args)

    
    sns.set_style("whitegrid")
    sns.set_context("paper", font_scale=1.5)

    
    fig = plt.figure(figsize=(13, 8))
    ax = fig.add_subplot(111)
    hm.init_bmap(axes=ax, nofillcontinents=True, projection="cyl")
    hm.plot_earth(interval=interval)

    if stas is not None:
        sta_locations = [s.earthmodel.site_info(n, 0)[0:2] for n in stas]
        hm.plot_locations(sta_locations, labels=stas, offmap_arrows=True,
                          marker="^", ms=14, mec="blue", mew=2,
                          alpha=1.0, mfc="none", arrow_color="blue", 
                          label_x_off=-10, label_y_off=-18, label_pts=10,)

    scatter_args = {'marker': "D", 's': 25, 'alpha': 0.5, 'c': "green", 'lw': 0}
    scatter_args.update(kwargs)
    
    hm.bmap.scatter(bulletin[:, 0], bulletin[:, 1], **scatter_args)
    
    true_bulletin=np.asarray(true_bulletin)
    hm.bmap.scatter(true_bulletin[:, 0], true_bulletin[:, 1], marker=".", s=25, alpha=0.3, c="red", lw=0)
    


    
stas = "ANMO,ELK,ILAR,KDAK,NEW,NVAR,PDAR,PFO,TXAR,ULM,YBH,YKA".split(",")

map_bulletin(netvisa_bulletin, truth, stas=stas, preset='wells')
map_bulletin(netvisa_bulletin, truth, stas=stas)
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
map_bulletin(sigvisa_bulletin_merged_123hf, truth, stas=stas, preset='wells')
map_bulletin(sigvisa_bulletin_merged_123hf, truth, stas=stas)
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
map_bulletin(sigvisa_thresholded, truth, stas=stas, preset="wells")
map_bulletin(sigvisa_thresholded, truth, stas=stas)
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
map_bulletin(sel3_bulletin, truth, stas=stas, preset="wells")
map_bulletin(sel3_bulletin, truth, stas=stas)
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
map_bulletin(leb_bulletin, truth, stas=stas)
map_bulletin(leb_bulletin, truth, stas=stas, preset="wells")
# Out:
# ANMO -10 -18 -106.4567 34.9462
# ELK -10 -18 -115.2388 40.7448
# ILAR -10 -20 -119.548533322 49.0
# KDAK -10 -20 -125.029432439 49.0
# NEW -10 -18 -117.12 48.26333
# NVAR -10 -18 -118.30355 38.429609
# PDAR -10 -18 -109.5579 42.7667
# PFO -10 -18 -116.4553 33.6092
# TXAR -10 -18 -106.266207748 33.0
# ULM -20 -18 -100.0 48.5167289879
# YBH -10 -18 -122.71038 41.73193
# YKA -10 -20 -113.429164961 49.0

# %%
# does sigvisa detect any denovo events *not* already in the ISC?
filter_de_novo(isc_wells_analyst_bulletin)

# turns out (from manual examination) the answer is no: the top five of these events are not in ISC, but all look false.
# Out:
# array([[ -1.13689761e+02,   3.30482980e+01,   1.07700320e+01,
#           1.20370869e+09,   6.09689000e+00,   6.17706153e+02,
#          -1.00000000e+00],
#        [ -1.10106961e+02,   3.75471390e+01,   2.23307700e+00,
#           1.20373742e+09,   2.84251000e+00,   2.31894869e+02,
#          -1.00000000e+00],
#        [ -1.10799249e+02,   3.72269130e+01,   2.17708950e+01,
#           1.20378328e+09,   5.00300900e+00,   3.83852372e+02,
#          -1.00000000e+00],
#        [ -1.03257896e+02,   4.76513250e+01,   7.57995000e-01,
#           1.20378329e+09,   5.33771700e+00,   2.03902747e+02,
#          -1.00000000e+00],
#        [ -1.17391107e+02,   4.25088710e+01,   6.91717200e+00,
#           1.20397442e+09,   4.45683700e+00,   1.65846999e+02,
#          -1.00000000e+00],
#        [ -1.05470000e+02,   3.92750000e+01,   2.00000000e+00,
#           1.20406895e+09,   2.90000000e+00,   0.00000000e+00,
#           1.52368600e+06],
#        [ -1.14578200e+02,   4.71096000e+01,   1.00000000e+01,
#           1.20437136e+09,   2.80000000e+00,   0.00000000e+00,
#           1.33639700e+06]])

# %% [markdown]
# # De novo event not in LEB

# %%
from sigvisa.source.event import Event
from sigvisa.infer.coarse_to_fine_init import EventRunSpec, ModelSpec, initialize_sg
#http://kampos.banatao.berkeley.edu:8001/sigvisa/bulletin/2279/signals.html
   
ev = Event(lon=-119.79, lat=39.60, depth=0.8, time=1204970823.4, mb=2.9)

hz=10
stas = "ANMO,ELK,ILAR,KDAK,NEW,NVAR,PDAR,PFO,TXAR,ULM,YBH,YKA".split(",")
phases = "P,Pn,Pg,Lg,Sn".split(',')
runid=25
band="freq_0.8_4.5"

rs = EventRunSpec(evs=[ev,], stas=stas,
                  initialize_events=True,
                  pre_s=20, post_s=60,
                  disable_conflict_checking=True)
ms1 = ModelSpec(template_model_type="param",
        wiggle_family="iid",
        wiggle_model_type="dummy",
        uatemplate_rate=1e-3,
        max_hz=hz,
        phases=phases,
        bands=(band,),
        runids=(runid,),
        min_mb=1.0,
        skip_levels=0,
        dummy_fallback=True,
        raw_signals=True,
        hack_param_constraint=True,
        vert_only=True)
sg = rs.build_sg(ms1)
initialize_sg(sg, ms1, rs)

for n in sg.extended_evnodes[1]:
    if n in sg.evnodes[1].values(): continue
    if n.deterministic(): continue
    n.parent_predict()
# Out:
# warning, no hparam prior specified for mult_wiggle_std , using dummy
# sg
# missing waveform Can't find data for sta TXAR chan SHZ time 1204971019
# waves
# added waves

# %%
def plot_sta(sta):
    try:
        wn = sg.station_waves[sta][0]
    except IndexError:
        s = Sigvisa()
        sta = s.get_default_sta(sta)
        wn = sg.station_waves[sta][0]


    f = plt.figure(figsize=(20, 5))
    ax = f.add_subplot(111)
    sns.set_style("white")
    sns.set_context("paper", font_scale=1.0)

    atime_args = {"color": "purple",
                  "top_rel": 0.95,
                  "bottom_rel": 0.05}
    wn.plot(ax=ax, model_lw=None, unass_lw=None, ev_lw=None, atime_args=atime_args)

    # clean up axes
    stime = wn.st+20
    etime = wn.et-20
    ax.set_xlim([stime, etime])

    tick_interval = 20
    nticks = np.floor((etime-stime)/tick_interval)
    ticks_base = np.arange(nticks+1) * tick_interval 
    ax.set_xticks(ticks_base + stime)
    labels = ["%d" % tick for tick in ticks_base]
    ax.set_xticklabels(labels, fontsize=18)
    #ax.set_xlabel("seconds")
    ax.set_yticks([])

    plt.xlabel('seconds', fontsize=18)
    plt.ylabel('', fontsize=18)

plot_sta("ELK")
plot_sta("YBH")
plot_sta("NVAR")
# Out:
# reading station detections...
# reading station detections...
# reading station detections...

# %%
blue, green, red, purple = sns.color_palette()[:4]

print np.asarray(blue)*255
print np.asarray(green)*255
print np.asarray(red)*255
print np.asarray(purple)*255
# Out:
# [  76.  114.  176.]
# [  85.  168.  104.]
# [ 196.   78.   82.]
# [ 129.  114.  178.]
