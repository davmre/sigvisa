# %%
from sigvisa import Sigvisa
from sigvisa.signals.io import load_event_station_chan
from sigvisa.graph.sigvisa_graph import SigvisaGraph
from sigvisa.source.event import get_event


s = Sigvisa()


tmtype = {'amp_transfer': 'param_sin1', 'tt_residual': 'constant_laplacian', 'coda_decay': 'param_linear_distmb', 'peak_offset': 'param_linear_mb', 'peak_decay': 'dummy'}

def load_sg(evid=5303023, sta='MKAR', chan='BHZ'):
    sg = SigvisaGraph(template_model_type=tmtype, template_shape='lin_polyexp', wiggle_model_type='dummy', wiggle_family='dummy',
                      phases=['P'], nm_type = 'ar', run_name='everything', iteration=2)
    
    ev = get_event(evid=evid)
    
    
    cursor = s.dbconn.cursor()
    wave = load_event_station_chan(evid, sta, chan, cursor=cursor).filter("%s;env" % 'freq_2.0_3.0')
    
    cursor.close()
    
    wn = sg.add_wave(wave=wave, fixed=True)
    
    #from sigvisa.models.noise.armodel.model import ARModel, ErrorModel
    #em = ErrorModel(mean=0, std=0.00054688)
    #ar = ARModel(params=np.array([.6, .1]), c=0.072982422, em=em)
    #wn.nm = ar
    
    sg.add_event(ev=ev, fixed=True)
    
    latent = [n for (k,n) in wn.parents.items() if 'latent_arrival' in k][0]
    
    np.random.seed(0)
    sg.parent_sample_all()
    return sg, wn, latent

#import cPickle as pickle
#with open('gibbs.sg', 'r') as f:
#    sg = pickle.load(f)
#    wn = sg.station_waves['FIA0'][0]

def debug_plot_all(sg, latent, wn, msg="", i=None):
    if msg =="" and i is not None:
        msg = "round %d" % i
    figure()
    wn.debugging_plot(ax=gca(), plot_mode="full")
    title('%s: observed signal, overall lp %f' % (msg,sg.current_log_p()))
    figure()
    latent.debugging_plot(ax=gca(), plot_mode="predict")
    title('%s: latent signal with predicted shape' % (msg,))
    figure()
    latent.debugging_plot(ax=gca(), plot_mode="wiggle")
    title('%s: wiggle lp %f' % (msg,latent.log_p()))
    figure()
    wn.debugging_plot(ax=gca(), plot_mode="noise")
    title('%s: noise lp %f' % (msg,wn.log_p()))
   

my_sg, my_wn, my_latent = load_sg()
debug_plot_all(my_sg, my_latent, my_wn)
# Out:
# ---------------------------------------------------------------------------
# ModelNotFoundError                        Traceback (most recent call last)
# <ipython-input-1-88cf9fe7e13d> in <module>()
#      59
#      60
# ---> 61 my_sg, my_wn, my_latent = load_sg()
#      62 debug_plot_all(my_sg, my_latent, my_wn)
#
# <ipython-input-1-88cf9fe7e13d> in load_sg(evid, sta, chan)
#      29     #wn.nm = ar
#      30
# ---> 31     sg.add_event(ev=ev, fixed=True)
#      32
#      33     latent = [n for (k,n) in wn.parents.items() if 'latent_arrival' in k][0]
#
# /home/dmoore/python/sigvisa/graph/sigvisa_graph.pyc in add_event(self, ev, basisids, tmshapes, sample_templates, fixed, eid)
#     450                 tg = self.template_generator(phase)
#     451                 wg = self.wiggle_generator(phase, self.base_srate)
# --> 452                 self.add_event_site_phase(tg, wg, site, phase, evnodes, sample_templates=sample_templates)
#     453
#     454         self._topo_sort()
#
# /home/dmoore/python/sigvisa/graph/sigvisa_graph.pyc in add_event_site_phase(self, tg, wg, site, phase, evnodes, sample_templates)
#     748                                                 evnodes=evnodes,
#     749                                                 low_bound = -15,
# --> 750                                                 high_bound = 15)
#     751         arrival_time_node = self.setup_tt(site, phase, evnodes=evnodes,
#     752                                           tt_residual_node=tt_residual_node,
#
# /home/dmoore/python/sigvisa/models/templates/lin_polyexp.py in create_param_node(self, graph, site, phase, band, chan, param, evnodes, atime_node, amp_transfer_node, children, **kwargs)
#      71             return graph.setup_site_param_node(param=param, site=site, phase=phase,
#      72                                                parents=[evnodes['loc'], evnodes['mb']],
# ---> 73                                                chan=chan, band=band, template=True, children=children, **kwargs)
#      74
#      75
#
# /home/dmoore/python/sigvisa/graph/sigvisa_graph.pyc in setup_site_param_node(self, **kwargs)
#     571             return self.setup_site_param_node_joint(**kwargs)
#     572         else:
# --> 573             return self.setup_site_param_node_indep(**kwargs)
#     574
#     575     def setup_site_arrival_nodes(self, eid, phase, site, chan, band, param_nodes):
#
# /home/dmoore/python/sigvisa/graph/sigvisa_graph.pyc in setup_site_param_node_indep(self, param, site, phase, parents, model_type, chan, band, basisid, modelid, children, low_bound, high_bound, initial_value, **kwargs)
#     651                                                  phase=phase, model_type=model_type,
#     652                                                  param=param, template_shape=self.template_shape,
# --> 653                                                  chan=chan, band=band, basisid=basisid)
#     654                 except ModelNotFoundError:
#     655                     if self.dummy_fallback:
#
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/functools32/functools32.pyc in wrapper(*args, **kwds)
#     398                     except KeyError:
#     399                         pass
# --> 400                 result = user_function(*args, **kwds)
#     401                 with lock:
#     402                     cache[key] = result     # record recent use of this key
#
# /home/dmoore/python/sigvisa/graph/sigvisa_graph.pyc in get_param_model_id(runid, sta, phase, model_type, param, template_shape, basisid, chan, band)
#      60         modelid = sorted(results, key = lambda x : -x[1])[0][0] # use the model with the most shrinkage iterations
#      61     except:
# ---> 62         raise ModelNotFoundError("no model found matching model_type = '%s' and site='%s' %s %s and phase='%s' and fitting_runid=%d and template_shape='%s' and param='%s' %s" % (model_type, sta, chan_cond, band_cond, phase, runid, template_shape, param, basisid_cond))
#      63     finally:
#      64         cursor.close()
#
# ModelNotFoundError: no model found matching model_type = 'constant_laplacian' and site='MK31'   and phase='P' and fitting_runid=20 and template_shape='lin_polyexp' and param='tt_residual'
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True

# %%
print my_wn.st
# Out:
# 1238982050.27

# %%
from sigvisa.infer.autoregressive_mcmc import gibbs_sweep, gibbs_update_wiggle_params
from sigvisa.infer.latent_arrival_mcmc_stupid import gibbs_sweep_python

gibbs_sweep(my_latent)
debug_plot_all(my_sg, my_latent, my_wn)
gibbs_update_wiggle_params(my_latent)
gibbs_sweep(my_latent)
debug_plot_all(my_sg, my_latent, my_wn)
# Out:
# 4961.0 67746.2612251
# resampled std [ 3.67049319] , previous 1.0
# resample params [ 1.33711611  0.11211175 -0.45286238] previous [ 0.7  0.2]

# %%
from sigvisa.infer.run_mcmc import run_open_world_MH
from sigvisa.infer.autoregressive_mcmc import gibbs_sweep

def plot_mcmc(sg, wn, latent):
    print "sweep", gibbs_sweep(latent)
    gibbs_update_wiggle_params(my_latent)
    gibbs_sweep(my_latent)
    for i in range(31):
        run_open_world_MH(sg, steps=1, enable_event_moves=False, enable_event_openworld=False, enable_template_openworld=False, 
                          disable_moves=[])
        
        if i % 10 == 0:
            figure()
            wn.debugging_plot(ax=gca(), plot_mode="full")
            title('step %d' % i)
            figure()
            latent.debugging_plot(ax=gca(), plot_mode="predict")
            title('step %d' % i)
        
plot_mcmc(my_sg, my_wn, my_latent)
# Out:
# sweep
# -6633.91273273
# 3187.0 29464.156241
# resampled std [ 3.05095187] , previous 3.18573830118
# resample params [ 2.31173696 -1.65248815  0.3395233 ] previous [ 2.26386711 -1.55639065  0.29133316]
# proposed atime
#  1238982075.31 vs current 1238982075.56
# 3187.0 28236.2345597
# resampled std [ 2.99425382] , previous 3.05095186522
# resample params [ 2.34292685 -1.71306967  0.36894721] previous [ 2.31173696 -1.65248815  0.3395233 ]
# running joint move on
#  coda_height
# after
#  coda_height joint -56475.8561734
# running joint move on coda_decay
# after
#  coda_decay joint -56475.8561734
# step 0 [('amp_transfer', 2.6641418507451302), ('coda_decay', -2.4022543681854356), ('coda_height', 2.2950078352995833), ('arrival_time', 1238982075.555449), ('peak_offset', 1.9074752048516341), ('tt_residual', -4.6182261528682602)]
# proposed atime
#  1238982075.91 vs current 1238982075.56
# 3187.0 27740.1755802
# resampled std [ 2.92801677] , previous 2.99425382101
# resample params [ 2.32068245 -1.67267556  0.35080812] previous [ 2.34292685 -1.71306967  0.36894721]
# running joint move on
#  coda_height
# after
#  coda_height joint -52131.0061834
# running joint move on coda_decay
# after
#  coda_decay joint -52131.0061834
# step 0 [('amp_transfer', 2.6641418507451302), ('coda_decay', -2.4022543681854356), ('coda_height', 2.2950078352995833), ('arrival_time', 1238982075.9136004), ('peak_offset', 1.9074752048516341), ('tt_residual', -4.2600747170162094)]
# proposed atime
#  1238982075.97 vs current 1238982075.91
# 3187.0 28773.1023181
# resampled std [ 3.02705996] , previous 2.9280167666
# resample params [ 2.29210324 -1.61462653  0.32130695] previous [ 2.32068245 -1.67267556  0.35080812]
# running joint move on
#  coda_height
# after
#  coda_height joint -53764.6739472
# running joint move on coda_decay
# after
#  coda_decay joint -53764.6739472
# step 0 [('amp_transfer', 2.6641418507451302), ('coda_decay', -2.4022543681854356), ('coda_height', 2.2950078352995833), ('arrival_time', 1238982075.9136004), ('peak_offset', 1.9074752048516341), ('tt_residual', -4.2600747170162094)]
# proposed atime
#  1238982074.51 vs current 1238982075.91
# 3187.0 32758.1571049
# resampled std [ 3.18219495] , previous 3.02705996428
# resample params [ 2.32373824 -1.6844977   0.35948707] previous [ 2.29210324 -1.61462653  0.32130695]
# running joint move on
#  coda_height
# after
#  coda_height joint -53736.7901866
# running joint move on coda_decay
# after
#  coda_decay joint -53736.7901866
# step 0 [('amp_transfer', 2.6641418507451302), ('coda_decay', -2.4022543681854356), ('coda_height', 2.2950078352995833), ('arrival_time', 1238982074.5142126), ('peak_offset', 1.9074752048516341), ('tt_residual', -5.6594625534725083)]
# proposed atime
#  1238982074.47 vs current 1238982074.51
# 3187.0 30578.3598446
# resampled std [ 3.10860695] , previous 3.18219495374
# resample params [ 2.31610916 -1.66778635  0.35016138] previous [ 2.32373824 -1.6844977   0.35948707]
# running joint move on
#  coda_height
# after
#  coda_height joint -55036.5040905
# running joint move on coda_decay
# after
#  coda_decay joint -55036.5040905
# step 0 [('amp_transfer', 2.6641418507451302), ('coda_decay', -2.4022543681854356), ('coda_height', 2.2950078352995833), ('arrival_time', 1238982071.7357771), ('peak_offset', 2.2528164908216119), ('tt_residual', -8.4378980221462143)]
# proposed atime
#  1238982071.75 vs current 1238982071.74
# 3242.5 29397.4710222
# resampled std [ 2.9716168] , previous 3.10860695234
# resample params [ 2.34399919 -1.71740817  0.37202604] previous [ 2.31610916 -1.66778635  0.35016138]
# running joint move on
#  coda_height
# after
#  coda_height joint -55626.895648
# running joint move on coda_decay
# after
#  coda_decay joint -55626.895648
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.7357771), ('peak_offset', 2.2528164908216119), ('tt_residual', -8.4378980221462143)]
# proposed atime
#  1238982071.91 vs current 1238982071.74
# 3267.0 29015.0592323
# resampled std [ 2.9610394] , previous 2.97161679806
# resample params [ 2.30041535 -1.62832971  0.32679881] previous [ 2.34399919 -1.71740817  0.37202604]
# running joint move on
#  coda_height
# after
#  coda_height joint -57479.4333619
# running joint move on coda_decay
# after
#  coda_decay joint -57479.4333619
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.7357771), ('peak_offset', 2.2528164908216119), ('tt_residual', -8.4378980221462143)]
# proposed atime
#  1238982071.07 vs current 1238982071.74
# 3267.0 33369.4837806
# resampled std [ 3.20539846] , previous 2.96103940062
# resample params [ 2.28429741 -1.60418707  0.31852311] previous [ 2.30041535 -1.62832971  0.32679881]
# running joint move on
#  coda_height
# after
#  coda_height joint -56518.8363485
# running joint move on coda_decay
# after
#  coda_decay joint -56518.8363485
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0683892), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1052859844875229)]
# proposed atime
#  1238982070.05 vs current 1238982071.07
# 3267.0 30539.7535423
# resampled std [ 3.08436167] , previous 3.2053984643
# resample params [ 2.31728817 -1.66603803  0.34745931] previous [ 2.28429741 -1.60418707  0.31852311]
# running joint move on
#  coda_height
# after
#  coda_height joint -56742.9187848
# running joint move on coda_decay
# after
#  coda_decay joint -56742.9187848
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0683892), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1052859844875229)]
# proposed atime
#  1238982070.52 vs current 1238982071.07
# 3267.0 30599.9953906
# resampled std [ 3.09590091] , previous 3.08436166624
# resample params [ 2.28525853 -1.60285071  0.3162287 ] previous [ 2.31728817 -1.66603803  0.34745931]
# running joint move on
#  coda_height
# after
#  coda_height joint -56670.6517298
# running joint move on coda_decay
# after
#  coda_decay joint -56670.6517298
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0683892), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1052859844875229)]
# proposed atime
#  1238982071.05 vs current 1238982071.07
# 3267.0 31184.4107119
# resampled std [ 3.11911583] , previous 3.09590091433
# resample params [ 2.30371933 -1.64332469  0.33833129] previous [ 2.28525853 -1.60285071  0.3162287 ]
# running joint move on
#  coda_height
# after
#  coda_height joint -55436.8796593
# running joint move on coda_decay
# after
#  coda_decay joint -55436.8796593
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0516791), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1219960274410141)]
# proposed atime
#  1238982071.29 vs current 1238982071.05
# 3267.0 29214.319171
# resampled std [ 3.03098522] , previous 3.11911582858
# resample params [ 2.34108782 -1.71445515  0.37227054] previous [ 2.30371933 -1.64332469  0.33833129]
# running joint move on
#  coda_height
# after
#  coda_height joint -55974.9899844
# running joint move on coda_decay
# after
#  coda_decay joint -55974.9899844
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0516791), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1219960274410141)]
# proposed atime
#  1238982070.13 vs current 1238982071.05
# 3267.0 33744.4495107
# resampled std [ 3.24856707] , previous 3.03098522417
# resample params [ 2.27996399 -1.5927756   0.31130554] previous [ 2.34108782 -1.71445515  0.37227054]
# running joint move on
#  coda_height
# after
#  coda_height joint -61382.5649552
# running joint move on coda_decay
# after
#  coda_decay joint -61382.5649552
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982071.0516791), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.1219960274410141)]
# proposed atime
#  1238982070.63 vs current 1238982071.05
# 3267.0 30590.1840937
# resampled std [ 3.05044229] , previous 3.24856707456
# resample params [ 2.3397166  -1.70973009  0.36864204] previous [ 2.27996399 -1.5927756   0.31130554]
# running joint move on
#  coda_height
# after
#  coda_height joint -58086.4981822
# running joint move on coda_decay
# after
#  coda_decay joint -58086.4981822
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982070.6318114), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5418637814235581)]
# proposed atime
#  1238982070.64 vs current 1238982070.63
# 3267.0 29870.8631583
# resampled std [ 2.97558439] , previous 3.0504422939
# resample params [ 2.33865316 -1.70923361  0.36915521] previous [ 2.3397166  -1.70973009  0.36864204]
# running joint move on
#  coda_height
# after
#  coda_height joint -55813.600114
# running joint move on coda_decay
# after
#  coda_decay joint -55813.600114
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982070.6408679), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5328072132778061)]
# proposed atime
#  1238982071.14 vs current 1238982070.64
# 3267.0 33520.1210513
# resampled std [ 3.20648551] , previous 2.97558438801
# resample params [ 2.29391608 -1.61822911  0.32286471] previous [ 2.33865316 -1.70923361  0.36915521]
# running joint move on
#  coda_height
# after
#  coda_height joint -56959.2025645
# running joint move on coda_decay
# after
#  coda_decay joint -56959.2025645
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982070.6408679), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5328072132778061)]
# proposed atime
#  1238982069.42 vs current 1238982070.64
# 3267.0 30489.8473072
# resampled std [ 3.10645822] , previous 3.2064855097
# resample params [ 2.36000263 -1.75350895  0.39202908] previous [ 2.29391608 -1.61822911  0.32286471]
# running joint move on
#  coda_height
# after
#  coda_height joint -56242.3948674
# running joint move on coda_decay
# after
#  coda_decay joint -56242.3948674
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982070.6408679), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5328072132778061)]
# proposed atime
#  1238982067.83 vs current 1238982070.64
# 3267.0 31987.238682
# resampled std [ 3.09912699] , previous 3.10645822002
# resample params [ 2.32639466 -1.68561479  0.35787904] previous [ 2.36000263 -1.75350895  0.39202908]
# running joint move on
#  coda_height
# after
#  coda_height joint -55287.8867192
# running joint move on coda_decay
# after
#  coda_decay joint -55287.8867192
# step 0 [('amp_transfer', 2.7751659288802681), ('coda_decay', -2.4022543681854356), ('coda_height', 2.4060319134347212), ('arrival_time', 1238982070.6408679), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5328072132778061)]
# proposed atime
#  1238982069.05 vs current 1238982070.64
# 3267.0 30893.0256701
# resampled std [ 3.07625502] , previous 3.09912699488
# resample params [ 2.35174113 -1.73578113  0.38271411] previous [ 2.32639466 -1.68561479  0.35787904]
# running joint move on
#  coda_height
# after
#  coda_height joint -60202.2410396
# running joint move on coda_decay
# after
#  coda_decay joint -60202.2410396
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982070.6408679), ('peak_offset', 2.2528164908216119), ('tt_residual', -9.5328072132778061)]
# proposed atime
#  1238982069.65 vs current 1238982070.64
# 3345.0 25611.8935864
# resampled std [ 2.77264048] , previous 3.07625501729
# resample params [ 2.22886832 -1.49041965  0.26069936] previous [ 2.35174113 -1.73578113  0.38271411]
# running joint move on
#  coda_height
# after
#  coda_height joint -57328.2272158
# running joint move on coda_decay
# after
#  coda_decay joint -57328.2272158
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982070.6194663), ('peak_offset', 2.25506333552483), ('tt_residual', -9.5542088570308579)]
# proposed atime
#  1238982070.89 vs current 1238982070.62
# 3345.5 21913.9953118
# resampled std [ 2.5657821] , previous 2.77264047574
# resample params [ 2.23139706 -1.49410186  0.26201826] previous [ 2.22886832 -1.49041965  0.26069936]
# running joint move on
#  coda_height
# after
#  coda_height joint -61399.2796475
# running joint move on coda_decay
# after
#  coda_decay joint -61399.2796475
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982070.8852737), ('peak_offset', 2.25506333552483), ('tt_residual', -9.2884014668178452)]
# proposed atime
#  1238982071.6 vs current 1238982070.89
# 3345.5 24140.9704041
# resampled std [ 2.71605188] , previous 2.56578210216
# resample params [ 2.1672444  -1.36536935  0.19727011] previous [ 2.23139706 -1.49410186  0.26201826]
# running joint move on
#  coda_height
# after
#  coda_height joint -56161.109026
# running joint move on coda_decay
# after
#  coda_decay joint -56161.109026
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982070.45 vs current 1238982071.6
# 3345.5 22618.9363754
# resampled std [ 2.59087682] , previous 2.71605187749
# resample params [ 2.21835105 -1.47195653  0.25274792] previous [ 2.1672444  -1.36536935  0.19727011]
# running joint move on
#  coda_height
# after
#  coda_height joint -56321.5173811
# running joint move on coda_decay
# after
#  coda_decay joint -56321.5173811
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982070.12 vs current 1238982071.6
# 3345.5 21815.637286
# resampled std [ 2.60411727] , previous 2.5908768157
# resample params [ 2.2099143  -1.45407279  0.24335309] previous [ 2.21835105 -1.47195653  0.25274792]
# running joint move on
#  coda_height
# after
#  coda_height joint -54238.2331053
# running joint move on coda_decay
# after
#  coda_decay joint -54238.2331053
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982071.22 vs current 1238982071.6
# 3345.5 22624.1665313
# resampled std [ 2.60434637] , previous 2.60411726576
# resample params [ 2.21645511 -1.46513627  0.24793626] previous [ 2.2099143  -1.45407279  0.24335309]
# running joint move on
#  coda_height
# after
#  coda_height joint -56694.2880239
# running joint move on coda_decay
# after
#  coda_decay joint -56694.2880239
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982070.94 vs current 1238982071.6
# 3345.5 23291.7979978
# resampled std [ 2.67002147] , previous 2.60434637381
# resample params [ 2.20036675 -1.43519617  0.23408289] previous [ 2.21645511 -1.46513627  0.24793626]
# running joint move on
#  coda_height
# after
#  coda_height joint -53864.4553269
# running joint move on coda_decay
# after
#  coda_decay joint -53864.4553269
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982068.76 vs current 1238982071.6
# 3345.5 22446.3087396
# resampled std [ 2.59188058] , previous 2.67002146932
# resample params [ 2.23903922 -1.5145014   0.27469906] previous [ 2.20036675 -1.43519617  0.23408289]
# running joint move on
#  coda_height
# after
#  coda_height joint -57608.516565
# running joint move on coda_decay
# after
#  coda_decay joint -57608.516565
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4022543681854356), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982071.5950022), ('peak_offset', 2.25506333552483), ('tt_residual', -8.5786729874324692)]
# proposed atime
#  1238982072.24 vs current 1238982071.6
# 3345.5 20234.0955878
# resampled std [ 2.4531033] , previous 2.59188058381
# resample params [ 2.23828493 -1.50723175  0.26810516] previous [ 2.23903922 -1.5145014   0.27469906]
# running joint move on
#  coda_height
# after
#  coda_height joint -54068.854219
# running joint move on coda_decay
# after
#  coda_decay joint -52823.7694884
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4041950133282604), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982073.80567), ('peak_offset', 2.0758677752943457), ('tt_residual', -6.3680051388454331)]
# proposed atime
#  1238982073.05 vs current 1238982073.81
# 3318.5 22052.0586771
# resampled std [ 2.58127553] , previous 2.45310330067
# resample params [ 2.19307941 -1.41808737  0.22427058] previous [ 2.23828493 -1.50723175  0.26810516]
# running joint move on
#  coda_height
# after
#  coda_height joint -54709.215455
# running joint move on coda_decay
# after
#  coda_decay joint -54709.215455
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4041950133282604), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982073.80567), ('peak_offset', 2.0758677752943457), ('tt_residual', -6.3680051388454331)]
# proposed atime
#  1238982075.49 vs current 1238982073.81
# 3318.5 20262.1494631
# resampled std [ 2.48484317] , previous 2.5812755283
# resample params [ 2.10447371 -1.23794986  0.13255922] previous [ 2.19307941 -1.41808737  0.22427058]
# running joint move on
#  coda_height
# after
#  coda_height joint -52844.2517064
# running joint move on coda_decay
# after
#  coda_decay joint -52844.2517064
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4041950133282604), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982075.5073726), ('peak_offset', 2.0734422209399921), ('tt_residual', -4.666302544088353)]
# proposed atime
#  1238982074.9 vs current 1238982075.51
# 3318.0 19853.1517737
# resampled std [ 2.44850534] , previous 2.48484317302
# resample params [ 2.11498884 -1.26091021  0.1449506 ] previous [ 2.10447371 -1.23794986  0.13255922]
# running joint move on
#  coda_height
# after
#  coda_height joint -56647.7545607
# running joint move on coda_decay
# after
#  coda_decay joint -56647.7545607
# step 0 [('amp_transfer', 3.1283431593229203), ('coda_decay', -2.4041950133282604), ('coda_height', 2.7592091438773734), ('arrival_time', 1238982072.8983223), ('peak_offset', 2.3571868485253802), ('tt_residual', -7.2753528179836167)]

# %%
debug_plot_all(my_sg, my_latent, my_wn)

# %%
dprk_sg, dprk_wn, dprk_latent = load_sg(evid=5393637, sta='FINES', chan='SHZ')
plot_mcmc(dprk_sg, dprk_wn, dprk_latent)
# Out:
# sweep
# 12888.7024124
# 3370.0 20017.3947207
# resampled std [ 2.38178947] , previous 2.44850533674
# resample params [ 2.14829297 -1.32738533  0.17815802] previous [ 2.11498884 -1.26091021  0.1449506 ]
# accepted peak move: new atime
#  1243213490.63 peak time 1243213493.2
# proposed atime
#  1243213490.84 vs current 1243213490.63
# 2767.0 860.252176588
# resampled std [ 0.56424367] , previous 1.0
# resample params [ 1.22988467  0.03296522 -0.26926322] previous [ 0.7  0.2]
# running joint move on
#  coda_height
# after
#  coda_height joint 15399.8141917
# running joint move on coda_decay
# after
#  coda_decay joint 15399.8141917
# step 0 [('amp_transfer', 0.93904225740362213), ('coda_decay', -2.4728817488199897), ('coda_height', 0.24028724774202992), ('arrival_time', 1243213490.6290307), ('peak_offset', 0.94428303053694229), ('tt_residual', -2.2010017119604299)]
# proposed atime
#  1243213490.38 vs current 1243213490.63
# 2766.5 158.96448816
# resampled std [ 0.24017195] , previous 0.56424367405
# resample params [ 1.33748533 -0.12748137 -0.21351566] previous [ 1.22988467  0.03296522 -0.26926322]
# running joint move on
#  coda_height
# after
#  coda_height joint 22103.2316811
# running joint move on coda_decay
# after
#  coda_decay joint 22103.2316811
# step 0 [('amp_transfer', 1.2113366189057555), ('coda_decay', -2.4728817488199897), ('coda_height', 0.51258160924416329), ('arrival_time', 1243213490.3765938), ('peak_offset', 0.94428303053694229), ('tt_residual', -2.453438588257427)]
# proposed atime
#  1243213490.57 vs current 1243213490.38
# 2831.0 50.9053581461
# resampled std [ 0.13335898] , previous 0.240171952937
# resample params [ 1.21403534  0.05401348 -0.27280089] previous [ 1.33748533 -0.12748137 -0.21351566]
# running joint move on
#  coda_height
# after
#  coda_height joint 26853.6359865
# running joint move on coda_decay
# after
#  coda_decay joint 26853.6359865
# step 0 [('amp_transfer', 1.1185486401175682), ('coda_decay', -2.4728817488199897), ('coda_height', 0.41979363045597595), ('arrival_time', 1243213490.3765938), ('peak_offset', 0.94428303053694229), ('tt_residual', -2.453438588257427)]
# proposed atime
#  1243213489.73 vs current 1243213490.38
# 2809.0 18.8889069909
# resampled std [ 0.08167244] , previous 0.133358979413
# resample params [ 1.25593106 -0.04204021 -0.21571651] previous [ 1.21403534  0.05401348 -0.27280089]
# running joint move on
#  coda_height
# after
#  coda_height joint 32893.1340674
# running joint move on coda_decay
# after
#  coda_decay joint 32893.1340674
# step 0 [('amp_transfer', 1.1185486401175682), ('coda_decay', -2.4728817488199897), ('coda_height', 0.41979363045597595), ('arrival_time', 1243213492.1195056), ('peak_offset', -1.7140636494336912), ('tt_residual', -0.71052677261411645)]
# accepted peak move: new atime
#  1243213489.24 peak time 1243213489.42
# proposed atime
#  1243213489.31 vs current 1243213489.24
# 2761.5 8.75832769293
# resampled std [ 0.05677399] , previous 0.0816724439504
# resample params [ 1.28662148  0.0262721  -0.31415459] previous [ 1.25593106 -0.04204021 -0.21571651]
# running joint move on
#  coda_height
# after
#  coda_height joint 34355.7975905
# running joint move on coda_decay
# after
#  coda_decay joint 34355.7975905
# step 0 [('amp_transfer', 1.1185486401175682), ('coda_decay', -2.4728817488199897), ('coda_height', 0.41979363045597595), ('arrival_time', 1243213489.0250561), ('peak_offset', -0.9164314397373492), ('tt_residual', -3.8049762927252004)]
# proposed atime
#  1243213490.07 vs current 1243213489.03
# 2765.5 5.09021169792
# resampled std [ 0.04337363] , previous 0.0567739876708
# resample params [ 1.28483921  0.03511361 -0.3224851 ] previous [ 1.28662148  0.0262721  -0.31415459]
# running joint move on
#  coda_height
# after
#  coda_height joint 36605.1157216
# running joint move on coda_decay
# after
#  coda_decay joint 36605.1157216
# step 0 [('amp_transfer', 0.58659465264503297), ('coda_decay', -2.4728817488199897), ('coda_height', -0.11216035701655924), ('arrival_time', 1243213489.2194471), ('peak_offset', 0.22062563739528707), ('tt_residual', -3.610585280533428)]
# proposed atime
#  1243213489.38 vs current 1243213489.22
# 2656.5 3.41834003522
# resampled std [ 0.03589927] , previous 0.0433736336411
# resample params [ 1.36205595  0.0517134  -0.41580125] previous [ 1.28483921  0.03511361 -0.3224851 ]
# running joint move on
#  coda_height
# after
#  coda_height joint 40327.2907277
# running joint move on coda_decay
# after
#  coda_decay joint 40327.2907277
# step 0 [('amp_transfer', -0.20664472362564057), ('coda_decay', -2.4728817488199897), ('coda_height', -0.90539973328723278), ('arrival_time', 1243213489.375241), ('peak_offset', 0.22062563739528707), ('tt_residual', -3.4547913752752493)]
# proposed atime
#  1243213490.16 vs current 1243213489.38
# 2468.5 3.56166943565
# resampled std [ 0.0374134] , previous 0.0358992747031
# resample params [ 1.45360034 -0.09190362 -0.3633897 ] previous [ 1.36205595  0.0517134  -0.41580125]
# running joint move on
#  coda_height
# after
#  coda_height joint 39182.690008
# running joint move on coda_decay
# after
#  coda_decay joint 39182.690008
# step 0 [('amp_transfer', -0.20664472362564057), ('coda_decay', -2.4728817488199897), ('coda_height', -0.90539973328723278), ('arrival_time', 1243213490.1604965), ('peak_offset', 0.22062563739528707), ('tt_residual', -2.669535943146343)]
# proposed atime
#  1243213490.14 vs current 1243213490.16
# 2468.5 4.41113177833
# resampled std [ 0.04243252] , previous 0.0374134004642
# resample params [ 1.42835101 -0.06095698 -0.36881543] previous [ 1.45360034 -0.09190362 -0.3633897 ]
# running joint move on
#  coda_height
# after
#  coda_height joint 38630.9802694
# running joint move on coda_decay
# after
#  coda_decay joint 38630.9802694
# step 0 [('amp_transfer', -0.20664472362564057), ('coda_decay', -2.4728817488199897), ('coda_height', -0.90539973328723278), ('arrival_time', 1243213491.0956242), ('peak_offset', -1.2287079213580425), ('tt_residual', -1.7344082080084036)]
# proposed atime
#  1243213490.54 vs current 1243213491.1
# 2449.5 5.05495713205
# resampled std [ 0.04514241] , previous 0.0424325190159
# resample params [ 1.44120535 -0.08918454 -0.35289133] previous [ 1.42835101 -0.06095698 -0.36881543]
# running joint move on
#  coda_height
# after
#  coda_height joint 39883.4234495
# running joint move on coda_decay
# after
#  coda_decay joint 39579.2398828
# step 0 [('amp_transfer', -1.139251550424015), ('coda_decay', 1.7805265831137356), ('coda_height', -1.8380065600856073), ('arrival_time', 1243213490.5387018), ('peak_offset', -1.2287079213580425), ('tt_residual', -2.2913306437689016)]
# proposed atime
#  1243213491.42 vs current 1243213490.54
# 1021.5 0.229211736923
# resampled std [ 0.01462579] , previous 0.0451424089426
# WARNING: Gibbs sampling new AR coefficients failed at 1;P;FIA0;SHZ;freq_2.0_3.0;latent_arrival; each of 10 samples returned nonstationary params. Reverting to old params.
# running joint move on coda_height
# after
#  coda_height joint 39553.8245636
# running joint move on coda_decay
# after coda_decay joint
# 39927.5183703
# step 0 [('amp_transfer', -1.139251550424015), ('coda_decay', 0.77598080261456914), ('coda_height', -1.8380065600856073), ('arrival_time', 1243213490.5387018), ('peak_offset', -1.2287079213580425), ('tt_residual', -2.2913306437689016)]
# accepted peak move: new atime
#  1243213493.66 peak time 1243213493.95
# proposed atime 1243213492.48 vs current 1243213493.66
# 1051.5 0.120410526225
# resampled std [ 0.01093747] , previous 0.0146257930574
# resample params [ 1.41772113  0.14318784 -0.56717494] previous [ 1.44120535 -0.08918454 -0.35289133]
# running joint move on
#  coda_height
# after coda_height joint -88191.0593545
# running joint move on coda_decay
# after
#  coda_decay joint -88191.0593545
# step 0 [('amp_transfer', -1.139251550424015), ('coda_decay', 0.77598080261456914), ('coda_height', -1.8380065600856073), ('arrival_time', 1243213492.4752262), ('peak_offset', -1.2287079213580425), ('tt_residual', -0.3548062525945852)]
# proposed atime
#  1243213492.65 vs current 1243213492.48
# 1051.5 15.3989436941
# resampled std [ 0.11973679] , previous 0.0109374688729
# resample params [ 1.59534209 -0.22444976 -0.37280854] previous [ 1.41772113  0.14318784 -0.56717494]
# running joint move on coda_height
# after
#  coda_height joint 39226.7372092
# running joint move on coda_decay
# after
#  coda_decay joint 35957.8264275
# step 0 [('amp_transfer', -1.139251550424015), ('coda_decay', -0.32358230820111866), ('coda_height', -1.8380065600856073), ('arrival_time', 1243213492.0423834), ('peak_offset', -0.32087588386025567), ('tt_residual', -0.78764898407041528)]
# proposed atime
#  1243213493.39 vs current 1243213492.04
# 1155.5 33.2097188934
# resampled std [ 0.16690385] , previous 0.119736793703
# resample params [ 1.6360471  -0.30195799 -0.33811644] previous [ 1.59534209 -0.22444976 -0.37280854]
# running joint move on
#  coda_height
# after
#  coda_height joint 36793.7948503
# running joint move on coda_decay
# after
#  coda_decay joint 36793.7948503
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213491.9205179), ('peak_offset', -0.16560732887118029), ('tt_residual', -0.90951449501096704)]
# proposed atime
#  1243213490.44 vs current 1243213491.92
# 1154.5 95.2529589012
# resampled std [ 0.2875957] , previous 0.166903846693
# resample params [ 2.02793876 -1.0775409   0.04787948] previous [ 1.6360471  -0.30195799 -0.33811644]
# running joint move on
#  coda_height
# after
#  coda_height joint 37310.0897579
# running joint move on coda_decay
# after
#  coda_decay joint 37310.0897579
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213491.16 vs current 1243213490.44
# 1154.5 145.485708328
# resampled std [ 0.3559567] , previous 0.287595702401
# resample params [ 1.68367229 -0.38032677 -0.30461333] previous [ 2.02793876 -1.0775409   0.04787948]
# running joint move on
#  coda_height
# after
#  coda_height joint 38296.9734997
# running joint move on coda_decay
# after
#  coda_decay joint 38296.9734997
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213492.2 vs current 1243213490.44
# 1154.5 149.429066839
# resampled std [ 0.35912806] , previous 0.355956695319
# resample params [ 1.71947289 -0.4548802  -0.2656927 ] previous [ 1.68367229 -0.38032677 -0.30461333]
# running joint move on
#  coda_height
# after
#  coda_height joint 38285.6545462
# running joint move on coda_decay
# after
#  coda_decay joint 38285.6545462
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213489.42 vs current 1243213490.44
# 1154.5 108.96660337
# resampled std [ 0.31527852] , previous 0.359128061142
# resample params [ 1.83320238 -0.68054754 -0.15376822] previous [ 1.71947289 -0.4548802  -0.2656927 ]
# running joint move on
#  coda_height
# after
#  coda_height joint 38131.8028509
# running joint move on coda_decay
# after
#  coda_decay joint 38131.8028509
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213491.81 vs current 1243213490.44
# 1154.5 121.0851669
# resampled std [ 0.31951396] , previous 0.315278516801
# resample params [ 1.7793418  -0.57397431 -0.2062584 ] previous [ 1.83320238 -0.68054754 -0.15376822]
# running joint move on
#  coda_height
# after
#  coda_height joint 38526.9536922
# running joint move on coda_decay
# after
#  coda_decay joint 38526.9536922
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213488.97 vs current 1243213490.44
# 1154.5 114.539517925
# resampled std [ 0.31861268] , previous 0.319513964231
# resample params [ 1.68045704 -0.38935121 -0.29223986] previous [ 1.7793418  -0.57397431 -0.2062584 ]
# running joint move on
#  coda_height
# after
#  coda_height joint 38393.3765049
# running joint move on coda_decay
# after
#  coda_decay joint 38393.3765049
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213490.82 vs current 1243213490.44
# 1154.5 84.9905563161
# resampled std [ 0.27054098] , previous 0.318612683834
# resample params [ 1.63484584 -0.28688005 -0.34904899] previous [ 1.68045704 -0.38935121 -0.29223986]
# running joint move on
#  coda_height
# after
#  coda_height joint 37727.5659235
# running joint move on coda_decay
# after
#  coda_decay joint 37727.5659235
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213488.21 vs current 1243213490.44
# 1154.5 101.654447878
# resampled std [ 0.30229738] , previous 0.270540980964
# resample params [ 1.6848035  -0.39408751 -0.29184141] previous [ 1.63484584 -0.28688005 -0.34904899]
# running joint move on
#  coda_height
# after
#  coda_height joint 38340.9140141
# running joint move on coda_decay
# after
#  coda_decay joint 38340.9140141
# step 0 [('amp_transfer', -1.2573267425830756), ('coda_decay', -0.32358230820111866), ('coda_height', -1.9560817522446678), ('arrival_time', 1243213490.4376559), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.3923764907079885)]
# proposed atime
#  1243213490.37 vs current 1243213490.44
# 1154.5 91.0907864503
# resampled std [ 0.28712879] , previous 0.302297375435
# resample params [ 1.61118517 -0.23582006 -0.37625322] previous [ 1.6848035  -0.39408751 -0.29184141]
# running joint move on
#  coda_height
# after
#  coda_height joint 37815.5614337
# running joint move on coda_decay
# after
#  coda_decay joint 37815.5614337
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213490.3701572), ('peak_offset', -0.16560732887118029), ('tt_residual', -2.4598751746374319)]
# proposed atime
#  1243213489.42 vs current 1243213490.37
# 1153.0 117.432641241
# resampled std [ 0.31200567] , previous 0.287128789932
# resample params [ 1.88611162 -0.77907613 -0.10832252] previous [ 1.61118517 -0.23582006 -0.37625322]
# running joint move on
#  coda_height
# after
#  coda_height joint 37381.2486095
# running joint move on coda_decay
# after
#  coda_decay joint 37381.2486095
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.4162962), ('peak_offset', -0.16560732887118029), ('tt_residual', -3.4137361727911184)]
# proposed atime
#  1243213488.48 vs current 1243213489.42
# 1153.0 169.261727108
# resampled std [ 0.37734415] , previous 0.312005672469
# resample params [ 1.92616663 -0.86149205 -0.06612701] previous [ 1.88611162 -0.77907613 -0.10832252]
# running joint move on
#  coda_height
# after
#  coda_height joint 37928.4204702
# running joint move on coda_decay
# after
#  coda_decay joint 37928.4204702
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.4162962), ('peak_offset', -0.16560732887118029), ('tt_residual', -3.4137361727911184)]
# proposed atime
#  1243213489.57 vs current 1243213489.42
# 1153.0 136.983036742
# resampled std [ 0.33898297] , previous 0.37734415207
# resample params [ 1.92598438 -0.85745512 -0.070033  ] previous [ 1.92616663 -0.86149205 -0.06612701]
# running joint move on
#  coda_height
# after
#  coda_height joint 38167.1930527
# running joint move on coda_decay
# after
#  coda_decay joint 38167.1930527
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.3881054), ('peak_offset', -0.13288040565041989), ('tt_residual', -3.4419270240026663)]
# proposed atime
#  1243213490.36 vs current 1243213489.39
# 1153.5 158.586361998
# resampled std [ 0.37775203] , previous 0.338982968306
# resample params [ 1.90557801 -0.82019218 -0.08686979] previous [ 1.92598438 -0.85745512 -0.070033  ]
# running joint move on
#  coda_height
# after
#  coda_height joint 37465.3030115
# running joint move on coda_decay
# after
#  coda_decay joint 37465.3030115
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.3881054), ('peak_offset', -0.13288040565041989), ('tt_residual', -3.4419270240026663)]
# proposed atime
#  1243213490.36 vs current 1243213489.39
# 1153.5 187.463055602
# resampled std [ 0.40433747] , previous 0.37775203437
# resample params [ 1.73088887 -0.47168055 -0.26068649] previous [ 1.90557801 -0.82019218 -0.08686979]
# running joint move on
#  coda_height
# after
#  coda_height joint 38100.4852761
# running joint move on coda_decay
# after
#  coda_decay joint 38100.4852761
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.3881054), ('peak_offset', -0.13288040565041989), ('tt_residual', -3.4419270240026663)]
# proposed atime
#  1243213489.93 vs current 1243213489.39
# 1153.5 176.494570593
# resampled std [ 0.39437826] , previous 0.404337465426
# resample params [ 1.94507959 -0.90013153 -0.04633349] previous [ 1.73088887 -0.47168055 -0.26068649]
# running joint move on
#  coda_height
# after
#  coda_height joint 38857.0070302
# running joint move on coda_decay
# after
#  coda_decay joint 38857.0070302
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.3881054), ('peak_offset', -0.13288040565041989), ('tt_residual', -3.4419270240026663)]
# proposed atime
#  1243213488.76 vs current 1243213489.39
# 1153.5 138.325806738
# resampled std [ 0.34141213] , previous 0.394378255915
# resample params [ 1.82697187 -0.66229434 -0.16608023] previous [ 1.94507959 -0.90013153 -0.04633349]
# running joint move on
#  coda_height
# after
#  coda_height joint 37791.9928964
# running joint move on coda_decay
# after
#  coda_decay joint 37791.9928964
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213489.3881054), ('peak_offset', -0.13288040565041989), ('tt_residual', -3.4419270240026663)]
# proposed atime
#  1243213489.21 vs current 1243213489.39
# 1153.5 187.80330756
# resampled std [ 0.40834048] , previous 0.34141212866
# resample params [ 1.8810048  -0.77271304 -0.10980352] previous [ 1.82697187 -0.66229434 -0.16608023]
# running joint move on
#  coda_height
# after
#  coda_height joint 36190.4101326
# running joint move on coda_decay
# after
#  coda_decay joint 36190.4101326
# step 0 [('amp_transfer', -1.3244367576187761), ('coda_decay', -0.32358230820111866), ('coda_height', -2.0231917672803683), ('arrival_time', 1243213487.1981857), ('peak_offset', 1.0619606801374302), ('tt_residual', -5.631846734161968)]
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True

# %%
dprk1_sg, dprk1_wn, dprk1_latent = load_sg(evid=5393637, sta='USRK', chan='SHZ')
plot_mcmc(dprk1_sg, dprk1_wn, dprk1_latent)
debug_plot_all(dprk1_sg, dprk1_latent,dprk1_wn)
# Out:
# sweep
# 8505.870426
# 3370.0 19796.5195636
# resampled std [ 2.45490024] , previous 2.38178947448
# resample params [ 2.09331449 -1.21563103  0.12123237] previous [ 2.14829297 -1.32738533  0.17815802]
# accepted peak move: new atime
#  1243212938.14 peak time 1243212940.57
# proposed atime
#  1243212936.36 vs current 1243212938.14
# 7885.0 35842.7944006
# resampled std [ 2.14581842] , previous 1.0
# resample params [ 1.32309778  0.07442609 -0.39966255] previous [ 0.7  0.2]
# running joint move on
#  coda_height
# after
#  coda_height joint -327735.690047
# running joint move on coda_decay
# after
#  coda_decay joint -327735.690047
# step 0 [('amp_transfer', 3.3387363340546186), ('coda_decay', -3.5685205821003798), ('coda_height', 2.6399813243930264), ('arrival_time', 1243212934.4732394), ('peak_offset', 1.4621841706391714), ('tt_residual', -5.9819299475781449)]
# proposed atime
#  1243212934.98 vs current 1243212934.47
# 7922.0 14188.4301599
# resampled std [ 1.32928316] , previous 2.14581841588
# resample params [ 1.23438633 -0.04436527 -0.19217516] previous [ 1.32309778  0.07442609 -0.39966255]
# running joint move on
#  coda_height
# after
#  coda_height joint -317851.044512
# running joint move on coda_decay
# after
#  coda_decay joint -317851.044512
# step 0 [('amp_transfer', 3.985060685100839), ('coda_decay', -3.5685205821003798), ('coda_height', 3.2863056754392468), ('arrival_time', 1243212934.4732394), ('peak_offset', 1.4621841706391714), ('tt_residual', -5.9819299475781449)]
# proposed atime
#  1243212932.01 vs current 1243212934.47
# 8380.5 4367.58763939
# resampled std [ 0.71947927] , previous 1.32928315578
# resample params [ 1.17549459  0.032739   -0.20991245] previous [ 1.23438633 -0.04436527 -0.19217516]
# running joint move on
#  coda_height
# after
#  coda_height joint -305471.407784
# running joint move on coda_decay
# after
#  coda_decay joint -305471.407784
# step 0 [('amp_transfer', 3.5451916245849171), ('coda_decay', -3.5685205821003798), ('coda_height', 2.8464366149233249), ('arrival_time', 1243212934.4732394), ('peak_offset', 1.4621841706391714), ('tt_residual', -5.9819299475781449)]
# proposed atime
#  1243212932.98 vs current 1243212934.47
# 8068.5 2026.5228788
# resampled std [ 0.50392517] , previous 0.719479272961
# resample params [ 1.41882292 -0.03050392 -0.3896278 ] previous [ 1.17549459  0.032739   -0.20991245]
# running joint move on
#  coda_height
# after
#  coda_height joint -301730.402232
# running joint move on coda_decay
# after
#  coda_decay joint -301730.402232
# step 0 [('amp_transfer', 3.5451916245849171), ('coda_decay', -3.5685205821003798), ('coda_height', 2.8464366149233249), ('arrival_time', 1243212934.4732394), ('peak_offset', 1.4621841706391714), ('tt_residual', -5.9819299475781449)]
# proposed atime
#  1243212933.71 vs current 1243212934.47
# 8068.5 1551.66366805
# resampled std [ 0.43638341] , previous 0.503925171411
# resample params [ 1.37175511 -0.01937652 -0.35379115] previous [ 1.41882292 -0.03050392 -0.3896278 ]
# running joint move on
#  coda_height
# after
#  coda_height joint -262484.541912
# running joint move on coda_decay
# after
#  coda_decay joint -261154.670231
# step 0 [('amp_transfer', 2.3448984651391598), ('coda_decay', -3.4657635675858725), ('coda_height', 1.6461434554775676), ('arrival_time', 1243212933.712729), ('peak_offset', 1.4621841706391714), ('tt_residual', -6.7424403922192582)]
# proposed atime
#  1243212933.07 vs current 1243212933.71
# 6618.0 2922.89123892
# resampled std [ 0.66566549] , previous 0.436383414574
# resample params [ 1.84416633 -0.71785786 -0.12688468] previous [ 1.37175511 -0.01937652 -0.35379115]
# running joint move on
#  coda_height
# after
#  coda_height joint -302441.586267
# running joint move on coda_decay
# after
#  coda_decay joint -302441.586267
# step 0 [('amp_transfer', 2.3448984651391598), ('coda_decay', -3.4657635675858725), ('coda_height', 1.6461434554775676), ('arrival_time', 1243212933.0658634), ('peak_offset', 1.4621841706391714), ('tt_residual', -7.3893059985272416)]
# proposed atime
#  1243212935.08 vs current 1243212933.07
# 6618.0 8232.18751074
# resampled std [ 1.12570587] , previous 0.665665486126
# resample params [ 1.6349541  -0.32281785 -0.31332471] previous [ 1.84416633 -0.71785786 -0.12688468]
# running joint move on
#  coda_height
# after
#  coda_height joint -296426.830386
# running joint move on coda_decay
# after
#  coda_decay joint -296426.830386
# step 0 [('amp_transfer', 2.3448984651391598), ('coda_decay', -3.4657635675858725), ('coda_height', 1.6461434554775676), ('arrival_time', 1243212933.0658634), ('peak_offset', 1.4621841706391714), ('tt_residual', -7.3893059985272416)]
# proposed atime
#  1243212933.8 vs current 1243212933.07
# 6618.0 8920.96734071
# resampled std [ 1.15500197] , previous 1.12570587146
# resample params [ 1.67403697 -0.39648547 -0.27887103] previous [ 1.6349541  -0.32281785 -0.31332471]
# running joint move on
#  coda_height
# after
#  coda_height joint -294405.614057
# running joint move on coda_decay
# after
#  coda_decay joint -294405.614057
# step 0 [('amp_transfer', 2.3448984651391598), ('coda_decay', -3.4657635675858725), ('coda_height', 1.6461434554775676), ('arrival_time', 1243212933.800504), ('peak_offset', 1.4621841706391714), ('tt_residual', -6.6546654002301224)]
# proposed atime
#  1243212934.36 vs current 1243212933.8
# 6618.0 9681.05776765
# resampled std [ 1.20831567] , previous 1.1550019712
# resample params [ 1.66181027 -0.38328832 -0.27993641] previous [ 1.67403697 -0.39648547 -0.27887103]
# running joint move on
#  coda_height
# after
#  coda_height joint -288121.887358
# running joint move on coda_decay
# after
#  coda_decay joint -288121.887358
# step 0 [('amp_transfer', 2.3448984651391598), ('coda_decay', -3.4657635675858725), ('coda_height', 1.6461434554775676), ('arrival_time', 1243212937.3771451), ('peak_offset', -0.30281779795697283), ('tt_residual', -3.0780243174664506)]
# proposed atime
#  1243212935.55 vs current 1243212937.38
# 6546.5 9177.83640472
# resampled std [ 1.18977122] , previous 1.20831567094
# resample params [ 1.66465611 -0.37821712 -0.28785011] previous [ 1.66181027 -0.38328832 -0.27993641]
# running joint move on
#  coda_height
# after
#  coda_height joint -294229.187154
# running joint move on coda_decay
# after
#  coda_decay joint -294229.187154
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212937.3771451), ('peak_offset', -0.30281779795697283), ('tt_residual', -3.0780243174664506)]
# proposed atime
#  1243212935.6 vs current 1243212937.38
# 6338.0 11534.2312927
# resampled std [ 1.35784198] , previous 1.18977121682
# resample params [ 1.67239845 -0.39875963 -0.27496791] previous [ 1.66465611 -0.37821712 -0.28785011]
# running joint move on
#  coda_height
# after
#  coda_height joint -301628.866436
# running joint move on coda_decay
# after
#  coda_decay joint -301628.866436
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212937.3771451), ('peak_offset', -0.30281779795697283), ('tt_residual', -3.0780243174664506)]
# proposed atime
#  1243212937.3 vs current 1243212937.38
# 6338.0 12082.8255636
# resampled std [ 1.37472262] , previous 1.35784197753
# resample params [ 1.73185219 -0.50222228 -0.23093712] previous [ 1.67239845 -0.39875963 -0.27496791]
# running joint move on
#  coda_height
# after
#  coda_height joint -295941.414655
# running joint move on coda_decay
# after
#  coda_decay joint -295941.414655
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212937.2957222), ('peak_offset', -0.30281779795697283), ('tt_residual', -3.1594471232525834)]
# accepted peak move: new atime
#  1243212936.36 peak time 1243212937.1
# proposed atime
#  1243212934.98 vs current 1243212936.36
# 6338.0 13857.4625267
# resampled std [ 1.47735348] , previous 1.374722623
# resample params [ 1.74053953 -0.52015304 -0.22179363] previous [ 1.73185219 -0.50222228 -0.23093712]
# running joint move on
#  coda_height
# after
#  coda_height joint -293497.04878
# running joint move on coda_decay
# after
#  coda_decay joint -293497.04878
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212936.3612661), ('peak_offset', -0.30281779795697283), ('tt_residual', -4.0939032332531937)]
# proposed atime
#  1243212938.09 vs current 1243212936.36
# 6338.0 14319.2568828
# resampled std [ 1.50485132] , previous 1.47735348141
# resample params [ 1.75680342 -0.54960909 -0.20855033] previous [ 1.74053953 -0.52015304 -0.22179363]
# running joint move on
#  coda_height
# after
#  coda_height joint -293409.011307
# running joint move on coda_decay
# after
#  coda_decay joint -293409.011307
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212936.1549475), ('peak_offset', -0.056515109089834037), ('tt_residual', -4.3002218501202591)]
# proposed atime
#  1243212937.46 vs current 1243212936.15
# 6342.0 14568.548813
# resampled std [ 1.51797403] , previous 1.50485131617
# resample params [ 1.74123448 -0.52064807 -0.22213095] previous [ 1.75680342 -0.54960909 -0.20855033]
# running joint move on
#  coda_height
# after
#  coda_height joint -297696.216266
# running joint move on coda_decay
# after
#  coda_decay joint -297696.216266
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212934.2703586), ('peak_offset', 1.0401498770602888), ('tt_residual', -6.1848108069531449)]
# proposed atime
#  1243212934.18 vs current 1243212934.27
# 6379.5 14016.2118296
# resampled std [ 1.46615042] , previous 1.51797402521
# resample params [ 1.78383876 -0.60333247 -0.18196062] previous [ 1.74123448 -0.52064807 -0.22213095]
# running joint move on
#  coda_height
# after
#  coda_height joint -304101.361282
# running joint move on coda_decay
# after
#  coda_decay joint -304101.361282
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212934.2703586), ('peak_offset', 1.0401498770602888), ('tt_residual', -6.1848108069531449)]
# proposed atime
#  1243212933.15 vs current 1243212934.27
# 6379.5 15424.1536343
# resampled std [ 1.56147024] , previous 1.4661504152
# resample params [ 1.70874893 -0.45783652 -0.25224329] previous [ 1.78383876 -0.60333247 -0.18196062]
# running joint move on
#  coda_height
# after
#  coda_height joint -291799.181604
# running joint move on coda_decay
# after
#  coda_decay joint -291799.181604
# step 0 [('amp_transfer', 2.0185859990690549), ('coda_decay', -3.4657635675858725), ('coda_height', 1.3198309894074627), ('arrival_time', 1243212934.2703586), ('peak_offset', 1.0401498770602888), ('tt_residual', -6.1848108069531449)]
# proposed atime
#  1243212935.02 vs current 1243212934.27
# 6379.5 14479.2529023
# resampled std [ 1.5084192] , previous 1.5614702392
# resample params [ 1.74570614 -0.53277504 -0.21435196] previous [ 1.70874893 -0.45783652 -0.25224329]
# running joint move on
#  coda_height
# after
#  coda_height joint -314508.849157
# running joint move on coda_decay
# after
#  coda_decay joint -314508.849157
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212934.2703586), ('peak_offset', 1.0401498770602888), ('tt_residual', -6.1848108069531449)]
# proposed atime
#  1243212935.07 vs current 1243212934.27
# 5792.5 24243.2202835
# resampled std [ 2.02408174] , previous 1.50841920116
# resample params [ 1.99961163 -1.02529278  0.02470347] previous [ 1.74570614 -0.53277504 -0.21435196]
# running joint move on
#  coda_height
# after
#  coda_height joint -272315.049219
# running joint move on coda_decay
# after
#  coda_decay joint -272315.049219
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212935.0478501), ('peak_offset', 1.0479553895310769), ('tt_residual', -5.4073192374341019)]
# proposed atime
#  1243212935.15 vs current 1243212935.05
# 5793.0 29409.4812861
# resampled std [ 2.24315028] , previous 2.02408173941
# resample params [ 2.00610329 -1.04263689  0.03552257] previous [ 1.99961163 -1.02529278  0.02470347]
# running joint move on
#  coda_height
# after
#  coda_height joint -280757.477415
# running joint move on coda_decay
# after
#  coda_decay joint -280757.477415
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212935.0478501), ('peak_offset', 1.0479553895310769), ('tt_residual', -5.4073192374341019)]
# proposed atime
#  1243212935.54 vs current 1243212935.05
# 5793.0 28346.1845077
# resampled std [ 2.20974688] , previous 2.24315028238
# resample params [ 2.03739216 -1.10534746  0.06700475] previous [ 2.00610329 -1.04263689  0.03552257]
# running joint move on
#  coda_height
# after
#  coda_height joint -285515.273798
# running joint move on coda_decay
# after
#  coda_decay joint -285515.273798
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212935.5376012), ('peak_offset', 1.0479553895310769), ('tt_residual', -4.9175681368939408)]
# proposed atime
#  1243212934.77 vs current 1243212935.54
# 5793.0 29730.891151
# resampled std [ 2.25806021] , previous 2.2097468779
# resample params [ 2.04332605 -1.11689649  0.07260665] previous [ 2.03739216 -1.10534746  0.06700475]
# running joint move on
#  coda_height
# after
#  coda_height joint -281071.78583
# running joint move on coda_decay
# after
#  coda_decay joint -281071.78583
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212934.7714479), ('peak_offset', 1.0479553895310769), ('tt_residual', -5.6837214724652299)]
# proposed atime
#  1243212933.9 vs current 1243212934.77
# 5793.0 31073.1609105
# resampled std [ 2.31611861] , previous 2.25806020917
# resample params [ 2.0246465  -1.07920219  0.05342824] previous [ 2.04332605 -1.11689649  0.07260665]
# running joint move on
#  coda_height
# after
#  coda_height joint -282032.424303
# running joint move on coda_decay
# after
#  coda_decay joint -282032.424303
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212933.89888), ('peak_offset', 1.0479553895310769), ('tt_residual', -6.5562893645398148)]
# proposed atime
#  1243212932.79 vs current 1243212933.9
# 5793.0 32639.6657864
# resampled std [ 2.37872505] , previous 2.31611860667
# resample params [ 2.0264283  -1.08271355  0.05520165] previous [ 2.0246465  -1.07920219  0.05342824]
# running joint move on
#  coda_height
# after
#  coda_height joint -276892.972816
# running joint move on coda_decay
# after
#  coda_decay joint -276892.972816
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212932.7855625), ('peak_offset', 1.0479553895310769), ('tt_residual', -7.6696068541638382)]
# proposed atime
#  1243212932.12 vs current 1243212932.79
# 5793.0 31777.4829524
# resampled std [ 2.33622294] , previous 2.37872504633
# resample params [ 2.09036359 -1.21122331  0.11981418] previous [ 2.0264283  -1.08271355  0.05520165]
# running joint move on
#  coda_height
# after
#  coda_height joint -284718.801366
# running joint move on coda_decay
# after
#  coda_decay joint -284718.801366
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212932.1247587), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.3304106490246781)]
# proposed atime
#  1243212931.6 vs current 1243212932.12
# 5793.0 31429.9976055
# resampled std [ 2.31576958] , previous 2.33622294324
# resample params [ 2.11239262 -1.2553996   0.14207284] previous [ 2.09036359 -1.21122331  0.11981418]
# running joint move on
#  coda_height
# after
#  coda_height joint -281871.711884
# running joint move on coda_decay
# after
#  coda_decay joint -281871.711884
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# proposed atime
#  1243212932.14 vs current 1243212931.6
# 5793.0 33725.8194287
# resampled std [ 2.41095228] , previous 2.31576957907
# resample params [ 2.03353154 -1.09649052  0.06189423] previous [ 2.11239262 -1.2553996   0.14207284]
# running joint move on
#  coda_height
# after
#  coda_height joint -273425.91134
# running joint move on coda_decay
# after
#  coda_decay joint -273425.91134
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# proposed atime
#  1243212934.53 vs current 1243212931.6
# 5793.0 32137.0467441
# resampled std [ 2.34529982] , previous 2.41095227873
# resample params [ 2.08339961 -1.19673734  0.11231982] previous [ 2.03353154 -1.09649052  0.06189423]
# running joint move on
#  coda_height
# after
#  coda_height joint -270073.664796
# running joint move on coda_decay
# after
#  coda_decay joint -270073.664796
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# proposed atime
#  1243212931.44 vs current 1243212931.6
# 5793.0 33302.4810358
# resampled std [ 2.3804721] , previous 2.34529982395
# resample params [ 2.0537101  -1.13339663  0.07867632] previous [ 2.08339961 -1.19673734  0.11231982]
# running joint move on
#  coda_height
# after
#  coda_height joint -272638.191327
# running joint move on coda_decay
# after
#  coda_decay joint -272638.191327
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# proposed atime
#  1243212931.51 vs current 1243212931.6
# 5793.0 32248.9449516
# resampled std [ 2.35639888] , previous 2.38047209928
# resample params [ 2.07781126 -1.18252931  0.10375354] previous [ 2.0537101  -1.13339663  0.07867632]
# running joint move on
#  coda_height
# after
#  coda_height joint -282428.041982
# running joint move on coda_decay
# after
#  coda_decay joint -282428.041982
# step 0 [('amp_transfer', 1.101017718296744), ('coda_decay', -3.4657635675858725), ('coda_height', 0.40226270863515179), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# proposed atime
#  1243212931.51 vs current 1243212931.6
# 5793.0 33601.2023299
# resampled std [ 2.41855151] , previous 2.35639888265
# resample params [ 2.02786952 -1.08477957  0.05594103] previous [ 2.07781126 -1.18252931  0.10375354]
# running joint move on
#  coda_height
# after
#  coda_height joint -289949.285936
# running joint move on coda_decay
# after
#  coda_decay joint -289949.285936
# step 0 [('amp_transfer', 0.67344348867382631), ('coda_decay', -3.4657635675858725), ('coda_height', -0.025311520987765901), ('arrival_time', 1243212931.5956378), ('peak_offset', 1.0479553895310769), ('tt_residual', -8.8595315711133011)]
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True
# /home/dmoore/.virtualenvs/sigvisa/local/lib/python2.7/site-packages/numpy/ma/core.py:3059: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   _mask[indx] = True
