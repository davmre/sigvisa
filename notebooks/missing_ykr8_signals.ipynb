# %%
from sigvisa.signals.io import fetch_waveform, fetch_waveform_sac
from sigvisa import Sigvisa

# %matplotlib inline
import matplotlib.pylab as plt

# %%
s = Sigvisa()
cursor = s.dbconn.cursor()

d = fetch_waveform_sac("YKR8", "SHZ", 1203624942, 1203624942+3600, cursor=cursor)

# %%
import obspy

fullpath="/home/dmoore/ctbt_data/llnl_data/YKA/sac2008001-091/2008.022.00.00.00.0000.CN.YKR8..SHZ.M.SAC"

first_offset = 53298440
samples_to_read = 72800

st = obspy.read(fullpath)
data = st[0].data[first_offset:first_offset+samples_to_read]

# %%
plt.figure(figsize=(15, 5))
plt.plot(data)

# %%
plt.figure(figsize=(15, 5))
plt.plot(d.data)
