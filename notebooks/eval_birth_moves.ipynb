# %%
import numpy as np
import sys
import os
import traceback


import pickle
import copy

from sigvisa import Sigvisa

from sigvisa.graph.sigvisa_graph import SigvisaGraph




from sigvisa.infer.run_mcmc import run_open_world_MH
from sigvisa.infer.mcmc_logger import MCMCLogger

from sigvisa.infer.template_mcmc import *
from sigvisa.plotting.plot import plot_with_fit, plot_with_fit_shapes, plot_pred_atimes
from sigvisa.signals.common import Waveform
from sigvisa.utils.fileutils import clear_directory, mkdir_p

# %%
def do_plot(wn, ax=None):
    if ax is None:
      f = plt.figure(figsize=(15,5))
      ax=f.add_subplot(111)
    shape_colors = plot_with_fit_shapes(fname=None, wn=wn, axes=ax, plot_wave=True)
    atimes = dict([("%d_%s" % (eid, phase), wn.get_template_params_for_arrival(eid=eid, phase=phase)[0]['arrival_time']) for (eid, phase) in wn.arrivals()])
    colors = dict([("%d_%s" % (eid, phase), shape_colors[eid]) for (eid, phase) in wn.arrivals()])
    plot_pred_atimes(dict(atimes), wn.get_wave(), axes=ax, color=colors, alpha=1.0, bottom_rel=-0.1, top_rel=0.0)
    return ax

# %% [markdown]
# # Likelihood of proposing true parameters

# %%
from sigvisa.experiments.one_station_templates_test import sample_template

def birth_proposal_likelihood(birth_proposal, nm_type='l1'):
    total_lp = 0 
    for seed in range(50):
        wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1, srate=1.0)
        tvals = dict([(k, n.get_value()) for (k, n) in templates[0].items()])

        sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                              wiggle_model_type="dummy", wiggle_family="dummy",
                              phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
        wn = sg.add_wave(wave)

        tg = sg.template_generator('UA')
        tg.hack_force_mean = np.log(wn.nm.c * 10)

        vals, lp = birth_proposal(sg, wn, fix_result=tvals)
        total_lp += lp
        if lp < -100:
            print seed, lp, tvals
    return total_lp

#print birth_proposal_likelihood(optimizing_birth_proposal)
print birth_proposal_likelihood(optimizing_birth_proposal, nm_type='ar')
# Out:
# 1 -191.362958811 {'coda_height': -0.85293612907148164, 'arrival_time': 1239916317.0220046, 'coda_decay': -0.7969819781497922, 'peak_decay': -3.5170141364670204, 'peak_offset': 1.0010979954674568}
# 5 -8660.90913982 {'coda_height': 1.0125909354021609, 'arrival_time': 1239916121.993171, 'coda_decay': -1.6379384685564746, 'peak_decay': -4.385762407725836, 'peak_offset': 0.4880179054022245}
# 7
#  -1577.69200832 {'coda_height': 0.18373248185394198, 'arrival_time': 1239915976.3082893, 'coda_decay': 0.5386572862055523, 'peak_decay': -2.5013280504761584, 'peak_offset': -0.22462486949978572}
# 8 -210.965243843 {'coda_height': 0.61552968646497619, 'arrival_time': 1239916773.4294028, 'coda_decay': -6.20443414916439, 'peak_decay': 0.219029798314323, 'peak_offset': -0.8675000546257785}
# 12
#  -180.038106402 {'coda_height': 0.11845215456787422, 'arrival_time': 1239916054.1628423, 'coda_decay': -3.559041404413458, 'peak_decay': -1.9146419150797795, 'peak_offset': 0.45376508229426044}
# 18
#  -1030.44770035 {'coda_height': 0.72383303294288681, 'arrival_time': 1239916550.3742418, 'coda_decay': -0.7153240091178721, 'peak_decay': -2.4247643377457906, 'peak_offset': 0.012368905660321228}
# 20 -325.319568898 {'coda_height': 0.018477094643563896, 'arrival_time': 1239916488.130801, 'coda_decay': -3.7517994025698433, 'peak_decay': -1.5836440737411845, 'peak_offset': 1.0786223202915073}
# 21 -2433.32319522 {'coda_height': -0.2999323051855371, 'arrival_time': 1239915948.7248807, 'coda_decay': -0.888799456464459, 'peak_decay': -3.211455495493942, 'peak_offset': 0.451984678604351}
# 24
#  -101.883902091 {'coda_height': -0.44545727481477498, 'arrival_time': 1239916860.0173032, 'coda_decay': -4.001483463240841, 'peak_decay': -1.0900264258761965, 'peak_offset': -0.6882436948804536}
# 25 -210.104351507 {'coda_height': 0.5042713953992638, 'arrival_time': 1239916770.1241367, 'coda_decay': -3.5889463376906616, 'peak_decay': -0.711619986309401, 'peak_offset': -1.8827159938814109}
# 27 -1249.13481522 {'coda_height': 0.66760816006883639, 'arrival_time': 1239916325.7214105, 'coda_decay': -3.7201011820804117, 'peak_decay': -1.7294733382323972, 'peak_offset': 0.6574880618425032}
# 29
#  -446.133511126 {'coda_height': 1.193719404192553, 'arrival_time': 1239916763.7599857, 'coda_decay': -2.015741108398095, 'peak_decay': -2.064493681017608, 'peak_offset': 0.9232118972048524}
# 30 -248.380081371 {'coda_height': -0.18943468158827009, 'arrival_time': 1239916544.143536, 'coda_decay': -2.898797285886606, 'peak_decay': -1.332750958159491, 'peak_offset': 1.0171445963575783}
# 43
#  -2563.09331468 {'coda_height': 0.53184527852557983, 'arrival_time': 1239916015.0545664, 'coda_decay': -1.1828514477478627, 'peak_decay': -2.971383316703859, 'peak_offset': 0.34531661282379483}
# 49
#  -108.196849594 {'coda_height': 1.1021923844649517, 'arrival_time': 1239916200.9644558, 'coda_decay': 0.8041992316893465, 'peak_decay': -1.8408152103585005, 'peak_offset': -0.4783842263993254}
# -20765.1422754

# %%
print birth_proposal_likelihood(birth_proposal)
print birth_proposal_likelihood(birth_proposal, nm_type='ar')
# Out:
# -634.759958712
# -717.375228226

# %% [markdown]
# # Debugging individual seeds

# %%
seed=21
nm_type='l1'

srate=1.0
wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1, srate=srate)
tvals = dict([(k, n.get_value()) for (k, n) in templates[0].items()])

sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                              wiggle_model_type="dummy", wiggle_family="dummy",
                              phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
wn = sg.add_wave(wave)

tg = sg.template_generator('UA')
tg.hack_force_mean = np.log(wn.nm.c * 10)

vals, lp, debug_info = optimizing_birth_proposal(sg, wn, fix_result=tvals, return_debug=True)

signal_diff_pos = debug_info['signal_diff_pos']
cdf2  = debug_info['cdf2']
peak_cdf = debug_info['peak_cdf']
fitting_window = debug_info['fitting_window']
atime_proposal_lp = debug_info['atime_proposal_lp']
peak_time_proposal_lp = debug_info['peak_time_proposal_lp']
proposal_lp = debug_info['proposal_lp']
proposal_mean = debug_info['proposal_mean']
proposal_prec = debug_info['proposal_prec']
lik_grad = debug_info['lik_grad']

print lp
# Out:
# -1879.51270092

# %%
plot(signal_diff_pos)

# %%
plot(cdf2)
print atime_proposal_lp
# Out:
# -1.52581185875

# %%
print peak_time_proposal_lp
plot(peak_cdf)
figure()
# Out:
# -2.04133317354

# %%
plot(fitting_window)
print proposal_lp
sample = np.array([vals['coda_height'], vals['peak_decay'], vals['coda_decay']])
print sample
print proposal_mean
cov = np.linalg.inv(proposal_prec)
print cov

# sanity check on gaussian density calculation
rv = scipy.stats.multivariate_normal(proposal_mean, cov)
lp = rv.logpdf(sample)
print lp
# Out:
# -1875.94555588
# [-0.6771857  -3.2114555  -0.88879946]
# [-0.29883238 -0.30360056 -3.51904373]
# [[ 0.02234487  0.01227603  0.00799452]
#  [ 0.01227603  0.03203949 -0.13918218]
#  [ 0.00799452 -0.13918218  0.86333985]]
# -1875.94555588

# %%
def build_decay(vals):
    coda_height = vals['coda_height']
    peak_decay = np.exp(vals['peak_decay'])
    coda_decay = np.exp(vals['coda_decay'])
    n = len(fitting_window)
    tlen = n / srate
    t = np.linspace(0, tlen, n)
    logt = np.log(t+1)

    pred_log_signal = coda_height - peak_decay * logt - t * coda_decay
    return pred_log_signal

print vals
pls = build_decay(vals)
plot(pls)
plot(np.log(fitting_window))

pmvals = {'coda_height': proposal_mean[0], 'peak_decay': proposal_mean[1], 'coda_decay': proposal_mean[2]}
pls2 = build_decay(pmvals)
plot(pls2)

print lik_grad(proposal_mean)
# Out:
# {'coda_height': -0.67718569877346491, 'arrival_time': 1239915948.7248807, 'coda_decay': -0.88879945646445901, 'peak_decay': -3.2114554954939418, 'peak_offset': 0.451984678604351}
# (3.4819705785715378, array([  2.78588662e-06,  -5.55641641e-06,  -1.11004049e-06]))

# %% [markdown]
# # Signal probability under proposal

# %%
from sigvisa.experiments.one_station_templates_test import sample_template

def birth_proposal_signal_prob(birth_helper, nm_type='l1', visualize=False, proposals_per_seed=10):
    lps = [] 
    for seed in range(50):
        wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1, srate=1.0)
        tvals = dict([(k, n.get_value()) for (k, n) in templates[0].items()])

        sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                              wiggle_model_type="dummy", wiggle_family="dummy",
                              phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
        wn = sg.add_wave(wave)

        tg = sg.template_generator('UA')
        tg.hack_force_mean = np.log(wn.nm.c * 10)

        lp1 = wn.log_p()
        
        if visualize:
            f = plt.figure(figsize=(15, 5))
            ax = f.add_subplot(111)
        
        for i in range(proposals_per_seed):
            lp_old, lp_new, log_qforward, log_qbackward, accept_move, revert_move = birth_helper(sg, wn)
            lp2 = wn.log_p()
            
            if visualize:
                do_plot(wn, ax=ax)
                
            revert_move()
            lps.append([lp2-lp1])
            
        if visualize:
            ax.set_title("seed %d" % seed)
            
        print "seed", seed, "probs", lp_new, lp_old, log_qforward, log_qbackward, lp2, lp1
        
    return np.array(lps)

#lp1 = birth_proposal_signal_prob(optimizing_birth_helper, proposals_per_seed=1, visualize=True, nm_type='l1')

print birth_proposal_signal_prob(optimizing_birth_helper, proposals_per_seed=1, visualize=True, nm_type='ar')
# Out:
# plotting uatemplate -1 as color (0.0, 0.29999999999999999, 1.0, 1.0)
# reading station detections...
# seed 0 probs 992.037512887 1029.25265949 -15.5601196014 0.0 1029.66469453 1030.25265949
# plotting uatemplate
#  -1 as color (0.0, 0.67647058823529416, 1.0, 1.0)
# reading station detections...
# seed 1 probs 1024.54259615 1045.26121942 -9.45051965836 0.0 1045.91813324 1046.26121942
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.78520499108734398, 1.0)
# reading station detections...
# seed 2 probs 963.665581675 954.91559534 -1.60375060872 0.0 978.950053903 955.91559534
# plotting uatemplate
#  -1 as color (0.072738772928526235, 0.99019607843137258, 0.89500316255534473, 1.0)
# reading station detections...
# seed 3 probs 1004.87486183 1015.55318231 -7.80764274587 0.0 1021.85884155 1016.55318231
# plotting uatemplate
#  -1 as color (0.0, 0.58235294117647063, 1.0, 1.0)
# reading station detections...
# seed 4 probs 726.97177117 421.960692868 5.49779955464 0.0 739.788494679 422.960692868
# plotting uatemplate
#  -1 as color (0.0, 0.73921568627450984, 1.0, 1.0)
# reading station detections...
# seed 5 probs 163.420465586 730.731828199 -1.84009590241 0.0 182.444333975 731.731828199
# plotting uatemplate
#  -1 as color (0.0, 0.86470588235294121, 0.99620493358633777, 1.0)
# reading station detections...
# seed 6 probs 986.647777264 1014.95073263 -11.911769583 0.0 1024.73963132 1015.95073263
# plotting uatemplate
#  -1 as color (0.0, 0.0019607843137254902, 1.0, 1.0)
# reading station detections...
# seed 7 probs 988.951972255 954.228241962 -1.48246772959 0.0 1003.9439764 955.228241962
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.83868092691622098, 1.0)
# reading station detections...
# seed 8 probs 784.615403771 820.5047593 -11.6122993295 0.0 812.445582861 821.5047593
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.517825311942959, 1.0)
# reading station detections...
# seed 9 probs 875.228437557 897.816066226 -7.88750980907 0.0 893.770525847 898.816066226
# plotting uatemplate
#  -1 as color (0.4142947501581275, 1.0, 0.55344718532574344, 1.0)
# reading station detections...
# seed 10 probs 1025.26913601 990.019580119 -1.01956053195 0.0 1038.0574595 991.019580119
# plotting uatemplate
#  -1 as color (0.0, 0.17450980392156862, 1.0, 1.0)
# reading station detections...
# seed 11 probs 967.468336077 986.396311234 -6.61467729274 0.0 987.308149634 987.396311234
# plotting uatemplate
#  -1 as color (0.0, 0.14313725490196066, 1.0, 1.0)
# reading station detections...
# seed 12 probs 916.658478549 948.324011706 -9.2576097785 0.0 938.246998068 949.324011706
# plotting uatemplate
#  -1 as color (0.0, 0.22156862745098038, 1.0, 1.0)
# reading station detections...
# seed 13 probs 958.749840073 890.74241886 -2.41081623607 0.0 974.939296689 891.74241886
# plotting uatemplate
#  -1 as color (0.0, 0.64509803921568631, 1.0, 1.0)
# reading station detections...
# seed 14 probs 911.607104977 624.573388057 3.16094032746 0.0 924.683568246 625.573388057
# plotting uatemplate
#  -1 as color (0.12333965844402275, 1.0, 0.84440227703984827, 1.0)
# reading station detections...
# seed 15 probs 940.12305452 951.461513302 2.43546946156 0.0 952.329920888 952.461513302
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.73172905525846699, 1.0)
# reading station detections...
# seed 16 probs 925.145540848 742.253729281 0.0442001904875 0.0 938.371915693 743.253729281
# plotting uatemplate
#  -1 as color (0.0, 0.0, 1.0, 1.0)
# reading station detections...
# seed 17 probs 888.170250879 909.616268403 -0.247369117097 0.0 905.261805689 910.616268403
# plotting uatemplate
#  -1 as color (0.38899430740037944, 1.0, 0.57874762808349156, 1.0)
# reading station detections...
# seed 18 probs 28.4560442142 786.280990114 -3.2719069499 0.0 47.8289392035 787.280990114
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.71390374331550799, 1.0)
# reading station detections...
# seed 19 probs 817.788177278 857.880030579 -6.32528409488 0.0 834.85691157 858.880030579
# plotting uatemplate
#  -1 as color (0.0, 0.86470588235294121, 0.99620493358633777, 1.0)
# reading station detections...
# seed 20 probs 956.83062233 978.88444634 -6.09571697748 0.0 974.819186291 979.88444634
# plotting uatemplate
#  -1 as color (0.12333965844402275, 1.0, 0.84440227703984827, 1.0)
# reading station detections...
# seed 21 probs 1006.41217931 1009.24254516 -0.557000609702 0.0 1019.948733 1010.24254516
# plotting uatemplate
#  -1 as color (0.0, 0.0, 0.80303030303030298, 1.0)
# reading station detections...
# seed 22 probs 957.189878498 983.0912851 -17.3332088051 0.0 982.778552376 984.0912851
# plotting uatemplate
#  -1 as color (0.0, 0.2372549019607843, 1.0, 1.0)
# reading station detections...
# seed 23 probs 704.015179545 159.386092479 3.74037108214 0.0 718.425362596 160.386092479
# plotting uatemplate
#  -1 as color (0.060088551549652112, 0.97450980392156861, 0.9076533839342189, 1.0)
# reading station detections...
# seed 24 probs 962.286238614 975.443067756 -3.47305482715 0.0 977.443554939 976.443067756
# plotting uatemplate
#  -1 as color (0.42694497153700184, 1.0, 0.54079696394686905, 1.0)
# reading station detections...
# seed 25 probs 867.9384008 854.767666781 -1.45275138161 0.0 885.624350069 855.767666781
# plotting uatemplate
#  -1 as color (0.022137887413029723, 0.9274509803921569, 0.94560404807084131, 1.0)
# reading station detections...
# seed 26 probs 998.074745259 1013.92038083 -6.43172420954 0.0 1015.07316617 1014.92038083
# plotting uatemplate
#  -1 as color (0.18659076533839339, 1.0, 0.78115117014547764, 1.0)
# reading station detections...
# seed 27 probs 975.687738397 827.311547481 1.45617656845 0.0 993.681432001 828.311547481
# plotting uatemplate
#  -1 as color (0.034788108791903853, 0.94313725490196076, 0.93295382669196714, 1.0)
# reading station detections...
# seed 28 probs 977.633059775 1029.44753175 -6.1269365331 0.0 996.368005496 1030.44753175
# plotting uatemplate
#  -1 as color (0.13598987982289687, 1.0, 0.8317520556609741, 1.0)
# reading station detections...
# seed 29 probs 641.210160672 665.91011815 -8.27811310342 0.0 662.460734501 666.91011815
# plotting uatemplate
#  -1 as color (0.11068943706514844, 1.0, 0.85705249841872255, 1.0)
# reading station detections...
# seed 30 probs 1017.61779891 1012.6137082 -5.72501057734 0.0 1031.19938509 1013.6137082
# plotting uatemplate
#  -1 as color (0.022137887413029723, 0.9274509803921569, 0.94560404807084131, 1.0)
# reading station detections...
# seed 31 probs 950.47059715 932.597427203 0.678236825418 0.0 968.115130249 933.597427203
# plotting uatemplate
#  -1 as color (0.22454142947501579, 1.0, 0.74320050600885512, 1.0)
# reading station detections...
# seed 32 probs 996.853324244 1011.63674586 -6.02134638696 0.0 1013.55898679 1012.63674586
# plotting uatemplate
#  -1 as color (0.0, 0.11176470588235295, 1.0, 1.0)
# reading station detections...
# seed 33 probs 955.078681583 942.119961301 1.01408084194 0.0 970.203696412 943.119961301
# plotting uatemplate
#  -1 as color (0.18659076533839339, 1.0, 0.78115117014547764, 1.0)
# reading station detections...
# seed
#  34 probs 1014.46914135 976.742388648 -3.62938854546 0.0 1032.53944039 977.742388648
# plotting uatemplate -1 as color (0.31309297912713452, 1.0, 0.65464895635673637, 1.0)
# reading station detections...
# seed
#  35 probs 796.258344095 811.03261086 -7.56615737737 0.0 810.162171717 812.03261086
# plotting uatemplate -1 as color (0.23719165085388991, 1.0, 0.73055028462998106, 1.0)
# reading station detections...
# seed
#  36 probs 941.001879244 955.878819133 -5.38079346275 0.0 961.121466412 956.878819133
# plotting uatemplate -1 as color (0.0, 0.19019607843137254, 1.0, 1.0)
# reading station detections...
# seed
#  37 probs 956.384305799 982.302149092 -13.6401247033 0.0 979.269123835 983.302149092
# plotting uatemplate -1 as color (0.21189120809614148, 1.0, 0.75585072738772952, 1.0)
# reading station detections...
# seed
#  38 probs 985.784242383 999.737370027 -6.76179914179 0.0 1002.90325047 1000.73737003
# plotting uatemplate -1 as color (0.0, 0.0, 0.89215686274509798, 1.0)
# reading station detections...
# seed
#  39 probs 973.266865703 1001.58868021 -5.37740733364 0.0 997.646145949 1002.58868021
# plotting uatemplate -1 as color (0.0, 0.0, 1.0, 1.0)
# reading station detections...
# seed
#  40 probs 967.612651194 791.462139849 0.479922832217 0.0 979.903045168 792.462139849
# plotting uatemplate -1 as color (0.047438330170777983, 0.95882352941176474, 0.92030360531309297, 1.0)
# reading station detections...
# seed
#  41 probs 958.892061041 884.542119346 3.64504185684 0.0 972.544104595 885.542119346
# plotting uatemplate -1 as color (0.0, 0.86470588235294121, 0.99620493358633777, 1.0)
# reading station detections...
# seed
#  42 probs 893.251760814 926.24236399 -12.8735431032 0.0 923.428459355 927.24236399
# plotting uatemplate -1 as color (0.0, 0.69215686274509802, 1.0, 1.0)
# reading station detections...
# seed
#  43 probs 933.399778392 942.949918869 -4.26510496247 0.0 947.553763635 943.949918869
# plotting uatemplate -1 as color (0.0, 0.0, 0.83868092691622098, 1.0)
# reading station detections...
# seed
#  44 probs 949.876948609 974.434870192 -10.0035610221 0.0 973.022018362 975.434870192
# plotting uatemplate -1 as color (0.4142947501581275, 1.0, 0.55344718532574344, 1.0)
# reading station detections...
# seed
#  45 probs 959.583240857 988.083300991 -10.3743125289 0.0 984.611139261 989.083300991
# plotting uatemplate -1 as color (0.0, 0.44117647058823528, 1.0, 1.0)
# reading station detections...
# seed
#  46 probs 721.580686195 754.390353656 1.9327572764 0.0 737.771049555 755.390353656
# plotting uatemplate -1 as color (0.47754585705249836, 1.0, 0.49019607843137258, 1.0)
# reading station detections...
# seed
#  47 probs 780.450676746 139.191014565 2.67418270472 0.0 799.786712718 140.191014565
# plotting uatemplate -1 as color (0.26249209361163817, 1.0, 0.70524984187223283, 1.0)
# reading station detections...
# seed
#  48 probs 993.219161547 845.025238731 0.620730522101 0.0 1005.12601902 846.025238731
# plotting uatemplate -1 as color (0.0, 0.0, 0.90998217468805698, 1.0)
# reading station detections...
# seed
#  49 probs 896.691335416 916.135267224 -8.01159715243 0.0 913.941477341 917.135267224
# [[ -5.87964958e-01]
#  [ -3.43086183e-01]
#  [  2.30344586e+01]
#  [  5.30565924e+00]
#  [  3.16827802e+02]
#  [ -5.49287494e+02]
#  [  8.78889869e+00]
#  [  4.87157344e+01]
#  [ -9.05917644e+00]
#  [ -5.04554038e+00]
#  [  4.70378794e+01]
#  [ -8.81616001e-02]
#  [ -1.10770136e+01]
#  [  8.31968778e+01]
#  [  2.99110180e+02]
#  [ -1.31592414e-01]
#  [  1.95118186e+02]
#  [ -5.35446271e+00]
#  [ -7.39452051e+02]
#  [ -2.40231190e+01]
#  [ -5.06526005e+00]
#  [  9.70618785e+00]
#  [ -1.31273272e+00]
#  [  5.58039270e+02]
#  [  1.00048718e+00]
#  [  2.98566833e+01]
#  [  1.52785344e-01]
#  [  1.65369885e+02]
#  [ -3.40795263e+01]
#  [ -4.44938365e+00]
#  [  1.75856769e+01]
#  [  3.45177030e+01]
#  [  9.22240929e-01]
#  [  2.70837351e+01]
#  [  5.47970517e+01]
#  [ -1.87043914e+00]
#  [  4.24264728e+00]
#  [ -4.03302526e+00]
#  [  2.16588044e+00]
#  [ -4.94253426e+00]
#  [  1.87440905e+02]
#  [  8.70019852e+01]
#  [ -3.81390464e+00]
#  [  3.60384477e+00]
#  [ -2.41285183e+00]
#  [ -4.47216173e+00]
#  [ -1.76193041e+01]
#  [  6.59595698e+02]
#  [  1.59100780e+02]
#  [ -3.19378988e+00]]

# %%
print np.mean(lp1), np.mean(lp2)
print np.median(lp1), np.median(lp2)

print np.sum(lp1>lp2)/float(len(lp1))
print np.sum(lp1>0)/float(len(lp1))
print np.sum(lp2>0)/float(len(lp1))
# Out:
# -10.1702869697 4.21916221985
# 13.4692894076 0.0278931851099
# 0.69
# 0.718
# 0.596

# %% [markdown]
# # Debugging visual proposal errors for specific seeds

# %%
from sigvisa.experiments.one_station_templates_test import sample_template

nm_type = 'ar'
seed = 29

wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1, srate=1.0)
tvals = dict([(k, n.get_value()) for (k, n) in templates[0].items()])

sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                      wiggle_model_type="dummy", wiggle_family="dummy",
                      phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
wn = sg.add_wave(wave)

tg = sg.template_generator('UA')
tg.hack_force_mean = np.log(wn.nm.c * 10)

lp1 = wn.log_p()

f = plt.figure(figsize=(15, 5))
ax = f.add_subplot(111)

sg.current_log_p_breakdown()


#import time
#np.random.seed(int(time.time()))
lp_old, lp_new, log_qforward, log_qbackward, accept_move, revert_move = optimizing_birth_helper(sg, wn)
lp2 = wn.log_p()

sg.current_log_p_breakdown()

do_plot(wn, ax=ax)

revert_move()

ax.set_title("seed %d" % seed)
print lp_new, lp_old, log_qforward, log_qbackward
print lp2, lp1 

#lp2 = birth_proposal_signal_prob(birth_helper)

#print birth_proposal_likelihood(optimizing_birth_proposal, nm_type='ar')
# Out:
# n_uatemplate: -1.0
# n_event: -3.8
# ev priors: ev 0.0
# tt_residual: ev 0.0
# ev global cost (n + priors + tt): -3.8
# coda_decay: ev 0.0 ua 0.0 total 0.0
# peak_decay: ev 0.0 ua 0.0 total 0.0
# peak_offset: ev 0.0 ua 0.0 total 0.0
# coda_height: ev 0.0 ua 0.0 total 0.0
# wiggles: ev 0.0 ua 0.0 total 0.0
# total param: ev 0.0 ua 0.0 total 0.0
# non signals: ev -3.8 ua -1.0 total -4.8
# signals: 666.9
# overall: 662.1
# official: 662.1
# n_uatemplate: -7.9
# n_event: -3.8
# ev priors: ev 0.0
# tt_residual: ev 0.0
# ev global cost (n + priors + tt): -3.8
# coda_decay: ev 0.0 ua -4.0 total -4.0
# peak_decay: ev 0.0 ua -1.1 total -1.1
# peak_offset: ev 0.0 ua -1.5 total -1.5
# coda_height: ev 0.0 ua -6.7 total -6.7
# wiggles: ev 0.0 ua 0.0 total 0.0
# total param: ev 0.0 ua -13.3 total -13.3
# non signals: ev -3.8 ua -21.3 total -25.0
# signals: 662.5
# overall: 637.4
# official: 637.4
# plotting uatemplate -1 as color (0.13598987982289687, 1.0, 0.8317520556609741, 1.0)
# reading station detections...
# 641.210160672 665.91011815 -8.27811310342 0.0
# 662.460734501 666.91011815

# %%
from sigvisa.experiments.one_station_templates_test import sample_template


nm_type = 'ar'
seed = 29

wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1, srate=1.0)
tvals = dict([(k, n.get_value()) for (k, n) in templates[0].items()])

sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                      wiggle_model_type="dummy", wiggle_family="dummy",
                      phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
wn = sg.add_wave(wave)

tg = sg.template_generator('UA')
tg.hack_force_mean = np.log(wn.nm.c * 10)

initial_vals, log_qforward, debug_info = optimizing_birth_proposal(sg, wn, return_debug=True)
print initial_vals
print tvals

signal_diff_pos = debug_info['signal_diff_pos']
cdf2  = debug_info['cdf2']
peak_cdf = debug_info['peak_cdf']
fitting_window = debug_info['fitting_window']
atime_proposal_lp = debug_info['atime_proposal_lp']
peak_time_proposal_lp = debug_info['peak_time_proposal_lp']
proposal_lp = debug_info['proposal_lp']
proposal_mean = debug_info['proposal_mean']
proposal_prec = debug_info['proposal_prec']
lik_grad = debug_info['lik_grad']
# Out:
# {'coda_height': -1.4713587114274078, 'arrival_time': 1239916122.0, 'coda_decay': -6.0, 'peak_decay': -1.9073421369045174, 'peak_offset': 1.3862943611198906}
# {'coda_height': 1.193719404192553, 'arrival_time': 1239916763.7599857, 'coda_decay': -2.015741108398095, 'peak_decay': -2.064493681017608, 'peak_offset': 0.9232118972048524}

# %%
plot(cdf2)

# %%
#plot(wn.get_value())
plot(signal_diff_pos)
print wn.nm.c
# Out:
# 0.09527

# %%
#plot(fitting_window)

srate = wn.srate
def build_decay(vals):
    coda_height = vals['coda_height']
    peak_decay = np.exp(vals['peak_decay'])
    coda_decay = np.exp(vals['coda_decay'])
    n = len(fitting_window)
    tlen = n / srate
    t = np.linspace(0, tlen, n)
    logt = np.log(t+1)

    pred_log_signal = coda_height - peak_decay * logt - t * coda_decay
    return pred_log_signal

pls = build_decay(initial_vals)
plot(pls)
plot(np.log(fitting_window))

pmvals = {'coda_height': proposal_mean[0], 'peak_decay': proposal_mean[1], 'coda_decay': proposal_mean[2]}
pls2 = build_decay(pmvals)
plot(pls2)

print pmvals
print initial_vals

cov = np.linalg.inv(proposal_prec)
#print lik_grad(proposal_mean)

rv = scipy.stats.multivariate_normal(proposal_mean, cov)
print rv.rvs(10)

import numdifftools as nd
f = lambda x : lik_grad(x)[0]
H = nd.Hessian(f).hessian(proposal_mean)
print H
print proposal_prec

print "covs"
print np.linalg.inv(H)
print cov

figure()
pdx = np.linspace(-4, -2, 100)
ll = np.array([lik_grad(np.array([proposal_mean[0], x, proposal_mean[2]]))[0] for x in pdx])
plot(pdx, ll)

figure()
p = np.exp(-ll)
p /= np.sum(p)
plot(pdx, p)

eps = 0.5
def g(x):
    ll1 = lik_grad(np.array([proposal_mean[0], x-eps, proposal_mean[2]]))[0]
    ll2 = lik_grad(np.array([proposal_mean[0], x+eps, proposal_mean[2]]))[0]
    return (ll2-ll1)/(2*eps)
g1 = g(proposal_mean[1]-eps)
g2 = g(proposal_mean[1]+eps)
h = (g2-g1)/(2*eps)
print h * 7.20924122909, proposal_prec[1,1]
    
gaussian = scipy.stats.norm(proposal_mean[1], cov[1,1])
p2 = gaussian.pdf(pdx)
p2 /= np.sum(p2)
plot(pdx, p2)

#gaussian2 = scipy.stats.norm(proposal_mean[1], 1/(h* 7.20924122909))
#p3 = gaussian2.pdf(pdx)
#p3 /= np.sum(p3)
#plot(pdx, p3)
# Out:
# {'coda_height': -0.51840337365550937, 'coda_decay': -3.5527912430931949, 'peak_decay': -2.911609557128533}
# {'coda_height': 0.084482626491042989, 'arrival_time': 1239916671.0, 'coda_decay': -3.7469602299116778, 'peak_decay': 1.0, 'peak_offset': 2.9444389791664403}
# [[-0.63244961 -5.14093545 -3.21478282]
#  [-0.27260259 -0.63663813 -3.84323213]
#  [-0.37129647 -2.38706168 -3.57258569]
#  [-0.59642629 -2.75815536 -3.78626661]
#  [-0.47281393 -1.26891404 -3.85739396]
#  [-0.39753826 -0.91569457 -3.76112273]
#  [-0.48719515 -3.98607953 -3.36723809]
#  [-0.88484232 -7.08585187 -3.20345372]
#  [-0.63933876 -3.05082759 -3.75762685]
#  [-0.3521804  -0.97849767 -3.75885142]]
# [[ 55.          -9.20534443 -43.32491817]
#  [ -9.20534443   1.66941602   8.36806371]
#  [-43.32491817   8.36806371  45.92553874]]
# [[ 396.50661415  -66.36327187 -318.01736536]
#  [ -66.36327187   12.03517259   60.32713833]
#  [-318.01736536   60.32713833  331.08690669]]
# covs
# [[  0.44520247   4.03467403  -0.3151634 ]
#  [  4.03467403  43.47645466  -4.11561465]
#  [ -0.3151634   -4.11561465   0.47436127]]
# [[ 0.04327239  0.34922879 -0.02206853]
#  [ 0.34922879  3.77721326 -0.35280057]
#  [-0.02206853 -0.35280057  0.04610654]]
# 20.1714486045
#  12.0351725907

# %% [markdown]
# # Optimizing STA/LTA params for likelihood

# %%
sg = SigvisaGraph(template_model_type="dummy", template_shape="lin_polyexp",
                      wiggle_model_type="dummy", wiggle_family="dummy",
                      phases="leb", nm_type = nm_type, wiggle_len_s = 60.0)
wave, templates = sample_template(seed=1, hardcoded=False, nm_type=nm_type, n_templates=1)
wn = sg.add_wave(wave)
wn.unfix_value()

def likelihood(**kwargs):
    total_logp = 0
    for seed in range(60):
        wave, templates = sample_template(seed=seed, hardcoded=False, nm_type=nm_type, n_templates=1)
        wn.set_value(wave.data)
        sdp = get_signal_diff_positive_part(wn, ())
        cdf2 = sta_lta_cdf2(sdp, **kwargs)
        true_atime = templates[0]['arrival_time'].get_value()
        true_logp = peak_log_p(cdf2, wn.st, wn.srate, true_atime)
        total_logp += true_logp
    return total_logp


for smooth_idx in (None, 5, 7, 11, 15, 17):
    for distsmooth_idx in (None, 3, 5):
        print smooth_idx, distsmooth_idx, likelihood(long_idx=30, short_idx=2, shift_idx=3, smooth_idx=smooth_idx, distsmooth_idx=distsmooth_idx)
# Out:
# None None
# -183.13599371
# None 3
# -183.13599371
# None 5
# -163.072496242
# 5 None
# -142.333676824
# 5 3
# -142.333676824
# 5 5
# -141.367037287
# 7 None
# -135.026276834
# 7 3
# -135.026276834
# 7 5
# -139.212728681
# 11 None
# -139.613858761
# 11 3
# -139.613858761
# 11 5
# -145.616899656
# 15 None
# -149.850643348
# 15 3
# -149.850643348
# 15 5
# -155.058188056
# 17 None
# -155.316458833
# 17 3
# -155.316458833
# 17 5
# -160.010629156

# %%
for long_idx in (10, 20, 30):
    for short_idx in (2, 4, 6):
        for shift_idx in (1, 2,3,4,6):
            print long_idx, short_idx, shift_idx, likelihood(short_idx=short_idx, long_idx=long_idx, 
                                                             smooth_idx=11, shift_idx=shift_idx,
                                                             distsmooth_idx=3)
# Out:
# 10 2 1
# -214.184471753
# 10 2 2
# -207.855692298
# 10 2 3
# -225.14143474
# 10 2 4
# -261.105822021
# 10 2 6
# -377.137359097
# 10 4 1
# -254.522723494
# 10 4 2
# -236.617697775
# 10 4 3
# -234.487501346
# 10 4 4
# -245.122237877
# 10 4 6
# -320.402708642
# 10 6 1
# -286.145319736
# 10 6 2
# -267.43032136
# 10 6 3
# -257.559279755
# 10 6 4
# -255.558608767
# 10 6 6
# -283.545294169
# 20 2 1
# -199.453355104
# 20 2 2
# -179.431650423
# 20 2 3
# -181.474902811
# 20 2 4
# -203.078483312
# 20 2 6
# -287.447603993
# 20 4 1
# -242.589605288
# 20 4 2
# -209.338224663
# 20 4 3
# -198.764086152
# 20 4 4
# -197.703011374
# 20 4 6
# -242.208945012
# 20 6 1
# -283.696639665
# 20 6 2
# -242.266393183
# 20 6 3
# -223.137867173
# 20 6 4
# -216.02169507
# 20 6 6
# -220.133645587
# 30 2 1
# -194.009152004
# 30 2 2
# -172.562307395
# 30 2 3
# -169.950655197
# 30 2 4
# -186.462015369
# 30 2 6
# -259.140594862
# 30 4 1
# -238.616111105
# 30 4 2
# -203.125722747
# 30 4 3
# -187.959198967
# 30 4 4
# -183.384220305
# 30 4 6
# -217.754839203
# 30 6 1
# -265.473126203
# 30 6 2
# -237.060552355
# 30 6 3
# -212.519232445
# 30 6 4
# -202.245154941
# 30 6 6
# -200.802168271

# %%
def fn1():
    return 1,2,3,4

stuff = fn1()
print stuff
# Out:
# (1, 2, 3, 4)
